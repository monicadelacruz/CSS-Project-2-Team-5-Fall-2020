# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Diabetes with Population Info by County 2017.csv") # importing data

# %%
data.head() #checking data out
# Out:
#            County    State  CountyFIPS Diabetes_Number Obesity_Number  \
# 0  Autauga County  Alabama        1001            5178          13489
# 1  Baldwin County  Alabama        1003           16707          48542
# 2  Barbour County  Alabama        1005            3400           8009
# 3     Bibb County  Alabama        1007            2371           6534
# 4   Blount County  Alabama        1009            6282          14227
#
#   Physical_Inactivity_Number  \
# 0                      12525
# 1                      40024
# 2                       5431
# 3                       5827
# 4                      14365
#
#   sex and age_total population_65 years and over_sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#    race_total population  race_total population_one race  \
# 0                  55200                           54170
# 1                 208107                          204535
# 2                  25782                           25429
# 3                  22527                           22340
# 4                  57645                           56710
#
#    race_total population_two or more races  ...  \
# 0                                     1030  ...
# 1                                     3572  ...
# 2                                      353  ...
# 3                                      187  ...
# 4                                      935  ...
#
#    sex and age_total population_21 years and over  \
# 0                                           39614
# 1                                          155502
# 2                                           19394
# 3                                           16864
# 4                                           42232
#
#    sex and age_total population_62 years and over  \
# 0                                            9403
# 1                                           49811
# 2                                            5658
# 3                                            4323
# 4                                           12400
#
#    sex and age_total population_65 years and over  \
# 0                                            8050
# 1                                           40665
# 2                                            4634
# 3                                            3661
# 4                                           10233
#
#    sex and age_total population_18 years and over_1  \
# 0                                             41831
# 1                                            162430
# 2                                             20346
# 3                                             17868
# 4                                             44177
#
#    sex and age_total population_18 years and over_male  \
# 0                                              20054
# 1                                              78104
# 2                                              10923
# 3                                               9578
# 4                                              21595
#
#    sex and age_total population_18 years and over_female  \
# 0                                              21777
# 1                                              84326
# 2                                               9423
# 3                                               8290
# 4                                              22582
#
#    sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# 0                                               92.1
# 1                                               92.6
# 2                                              115.9
# 3                                              115.5
# 4                                               95.6
#
#    sex and age_total population_65 years and over_1  \
# 0                                              8050
# 1                                             40665
# 2                                              4634
# 3                                              3661
# 4                                             10233
#
#    sex and age_total population_65 years and over_male  \
# 0                                               3488
# 1                                              18870
# 2                                               2004
# 3                                               1633
# 4                                               4540
#
#    sex and age_total population_65 years and over_female
# 0                                               4562
# 1                                              21795
# 2                                               2630
# 3                                               2028
# 4                                               5693
#
# [5 rows x 95 columns]

# %%
data.info(verbose = True) #checking data types and variables, 
                          # seems like Diabetes_Number (and some others) are not integers...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 95 columns):
#  #   Column                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                --------------  -----
#  0   County                                                                                                                                                3220 non-null   object
#  1   State                                                                                                                                                 3220 non-null   object
#  2   CountyFIPS                                                                                                                                            3220 non-null   int64
#  3   Diabetes_Number                                                                                                                                       3220 non-null   object
#  4   Obesity_Number                                                                                                                                        3220 non-null   object
#  5   Physical_Inactivity_Number                                                                                                                            3220 non-null   object
#  6   sex and age_total population_65 years and over_sex ratio (males per 100 females)                                                                      3220 non-null   object
#  7   race_total population                                                                                                                                 3220 non-null   int64
#  8   race_total population_one race                                                                                                                        3220 non-null   int64
#  9   race_total population_two or more races                                                                                                               3220 non-null   int64
#  10  race_total population_one race_1                                                                                                                      3220 non-null   int64
#  11  race_total population_one race_white                                                                                                                  3220 non-null   int64
#  12  race_total population_one race_black or african american                                                                                              3220 non-null   int64
#  13  race_total population_one race_american indian and alaska native                                                                                      3220 non-null   int64
#  14  race_total population_one race_american indian and alaska native_cherokee tribal grouping                                                             3220 non-null   int64
#  15  race_total population_one race_american indian and alaska native_chippewa tribal grouping                                                             3220 non-null   int64
#  16  race_total population_one race_american indian and alaska native_navajo tribal grouping                                                               3220 non-null   int64
#  17  race_total population_one race_american indian and alaska native_sioux tribal grouping                                                                3220 non-null   int64
#  18  race_total population_one race_asian                                                                                                                  3220 non-null   int64
#  19  race_total population_one race_asian_asian indian                                                                                                     3220 non-null   int64
#  20  race_total population_one race_asian_chinese                                                                                                          3220 non-null   int64
#  21  race_total population_one race_asian_filipino                                                                                                         3220 non-null   int64
#  22  race_total population_one race_asian_japanese                                                                                                         3220 non-null   int64
#  23  race_total population_one race_asian_korean                                                                                                           3220 non-null   int64
#  24  race_total population_one race_asian_vietnamese                                                                                                       3220 non-null   int64
#  25  race_total population_one race_asian_other asian                                                                                                      3220 non-null   int64
#  26  race_total population_one race_native hawaiian and other pacific islander                                                                             3220 non-null   int64
#  27  race_total population_one race_native hawaiian and other pacific islander_native hawaiian                                                             3220 non-null   int64
#  28  race_total population_one race_native hawaiian and other pacific islander_guamanian or chamorro                                                       3220 non-null   int64
#  29  race_total population_one race_native hawaiian and other pacific islander_samoan                                                                      3220 non-null   int64
#  30  race_total population_one race_native hawaiian and other pacific islander_other pacific islander                                                      3220 non-null   int64
#  31  race_total population_one race_some other race                                                                                                        3220 non-null   int64
#  32  race_total population_two or more races_1                                                                                                             3220 non-null   int64
#  33  race_total population_two or more races_white and black or african american                                                                           3220 non-null   int64
#  34  race_total population_two or more races_white and american indian and alaska native                                                                   3220 non-null   int64
#  35  race_total population_two or more races_white and asian                                                                                               3220 non-null   int64
#  36  race_total population_two or more races_black or african american and american indian and alaska native                                               3220 non-null   int64
#  37  race alone or in combination with one or more other races_total population                                                                            3220 non-null   int64
#  38  race alone or in combination with one or more other races_total population_white                                                                      3220 non-null   int64
#  39  race alone or in combination with one or more other races_total population_black or african american                                                  3220 non-null   int64
#  40  race alone or in combination with one or more other races_total population_american indian and alaska native                                          3220 non-null   int64
#  41  race alone or in combination with one or more other races_total population_asian                                                                      3220 non-null   int64
#  42  race alone or in combination with one or more other races_total population_native hawaiian and other pacific islander                                 3220 non-null   int64
#  43  race alone or in combination with one or more other races_total population_some other race                                                            3220 non-null   int64
#  44  hispanic or latino and race_total population                                                                                                          3220 non-null   int64
#  45  hispanic or latino and race_total population_hispanic or latino (of any race)                                                                         3220 non-null   int64
#  46  hispanic or latino and race_total population_hispanic or latino (of any race)_mexican                                                                 3220 non-null   int64
#  47  hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican                                                            3220 non-null   int64
#  48  hispanic or latino and race_total population_hispanic or latino (of any race)_cuban                                                                   3220 non-null   int64
#  49  hispanic or latino and race_total population_hispanic or latino (of any race)_other hispanic or latino                                                3220 non-null   int64
#  50  hispanic or latino and race_total population_not hispanic or latino                                                                                   3220 non-null   int64
#  51  hispanic or latino and race_total population_not hispanic or latino_white alone                                                                       3220 non-null   int64
#  52  hispanic or latino and race_total population_not hispanic or latino_black or african american alone                                                   3220 non-null   int64
#  53  hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone                                           3220 non-null   int64
#  54  hispanic or latino and race_total population_not hispanic or latino_asian alone                                                                       3220 non-null   int64
#  55  hispanic or latino and race_total population_not hispanic or latino_native hawaiian and other pacific islander alone                                  3220 non-null   int64
#  56  hispanic or latino and race_total population_not hispanic or latino_some other race alone                                                             3220 non-null   int64
#  57  hispanic or latino and race_total population_not hispanic or latino_two or more races                                                                 3220 non-null   int64
#  58  hispanic or latino and race_total population_not hispanic or latino_two or more races_two races including some other race                             3220 non-null   int64
#  59  hispanic or latino and race_total population_not hispanic or latino_two or more races_two races excluding some other race -  and three or more races  3220 non-null   int64
#  60  total housing units                                                                                                                                   3220 non-null   int64
#  61  citizen -  voting age population_citizen -  18 and over population                                                                                    3220 non-null   int64
#  62  citizen -  voting age population_citizen -  18 and over population_male                                                                               3220 non-null   int64
#  63  citizen -  voting age population_citizen -  18 and over population_female                                                                             3220 non-null   int64
#  64  sex and age_total population                                                                                                                          3220 non-null   int64
#  65  sex and age_total population_male                                                                                                                     3220 non-null   int64
#  66  sex and age_total population_female                                                                                                                   3220 non-null   int64
#  67  sex and age_total population_sex ratio (males per 100 females)                                                                                        3220 non-null   float64
#  68  sex and age_total population_under 5 years                                                                                                            3220 non-null   int64
#  69  sex and age_total population_5 to 9 years                                                                                                             3220 non-null   int64
#  70  sex and age_total population_10 to 14 years                                                                                                           3220 non-null   int64
#  71  sex and age_total population_15 to 19 years                                                                                                           3220 non-null   int64
#  72  sex and age_total population_20 to 24 years                                                                                                           3220 non-null   int64
#  73  sex and age_total population_25 to 34 years                                                                                                           3220 non-null   int64
#  74  sex and age_total population_35 to 44 years                                                                                                           3220 non-null   int64
#  75  sex and age_total population_45 to 54 years                                                                                                           3220 non-null   int64
#  76  sex and age_total population_55 to 59 years                                                                                                           3220 non-null   int64
#  77  sex and age_total population_60 to 64 years                                                                                                           3220 non-null   int64
#  78  sex and age_total population_65 to 74 years                                                                                                           3220 non-null   int64
#  79  sex and age_total population_75 to 84 years                                                                                                           3220 non-null   int64
#  80  sex and age_total population_85 years and over                                                                                                        3220 non-null   int64
#  81  sex and age_total population_median age (years)                                                                                                       3220 non-null   float64
#  82  sex and age_total population_under 18 years                                                                                                           3220 non-null   int64
#  83  sex and age_total population_16 years and over                                                                                                        3220 non-null   int64
#  84  sex and age_total population_18 years and over                                                                                                        3220 non-null   int64
#  85  sex and age_total population_21 years and over                                                                                                        3220 non-null   int64
#  86  sex and age_total population_62 years and over                                                                                                        3220 non-null   int64
#  87  sex and age_total population_65 years and over                                                                                                        3220 non-null   int64
#  88  sex and age_total population_18 years and over_1                                                                                                      3220 non-null   int64
#  89  sex and age_total population_18 years and over_male                                                                                                   3220 non-null   int64
#  90  sex and age_total population_18 years and over_female                                                                                                 3220 non-null   int64
#  91  sex and age_total population_18 years and over_sex ratio (males per 100 females)                                                                      3220 non-null   float64
#  92  sex and age_total population_65 years and over_1                                                                                                      3220 non-null   int64
#  93  sex and age_total population_65 years and over_male                                                                                                   3220 non-null   int64
#  94  sex and age_total population_65 years and over_female                                                                                                 3220 non-null   int64
# dtypes: float64(3), int64(86), object(6)
# memory usage: 2.3+ MB

# %%
#data.Diabetes_Number = data.Diabetes_Number.astype(int) # gets error bc of "No Data" value, not coercable to an integer

# %%
clean = data[data.Diabetes_Number != "Suppressed"] 
clean = clean[clean.Obesity_Number != "No Data"]
clean = clean[clean.iloc[:,6] != "-"]
# cleaning data to drop these rows bc we can't do anything with them

# %%
clean.iloc[:,3:6] = clean.iloc[:,3:6].astype(int) 
clean.iloc[:,6] = clean.iloc[:,6].astype(float)
# making all number columns into integer or float data types

# %%
clean.info(verbose = True) # double checking data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3112 entries, 0 to 3219
# Data columns (total 95 columns):
#  #   Column                                                                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                                                                --------------  -----
#  0   County                                                                                                                                                3112 non-null   object
#  1   State                                                                                                                                                 3112 non-null   object
#  2   CountyFIPS                                                                                                                                            3112 non-null   int64
#  3   Diabetes_Number                                                                                                                                       3112 non-null   int64
#  4   Obesity_Number                                                                                                                                        3112 non-null   int64
#  5   Physical_Inactivity_Number                                                                                                                            3112 non-null   int64
#  6   sex and age_total population_65 years and over_sex ratio (males per 100 females)                                                                      3112 non-null   float64
#  7   race_total population                                                                                                                                 3112 non-null   int64
#  8   race_total population_one race                                                                                                                        3112 non-null   int64
#  9   race_total population_two or more races                                                                                                               3112 non-null   int64
#  10  race_total population_one race_1                                                                                                                      3112 non-null   int64
#  11  race_total population_one race_white                                                                                                                  3112 non-null   int64
#  12  race_total population_one race_black or african american                                                                                              3112 non-null   int64
#  13  race_total population_one race_american indian and alaska native                                                                                      3112 non-null   int64
#  14  race_total population_one race_american indian and alaska native_cherokee tribal grouping                                                             3112 non-null   int64
#  15  race_total population_one race_american indian and alaska native_chippewa tribal grouping                                                             3112 non-null   int64
#  16  race_total population_one race_american indian and alaska native_navajo tribal grouping                                                               3112 non-null   int64
#  17  race_total population_one race_american indian and alaska native_sioux tribal grouping                                                                3112 non-null   int64
#  18  race_total population_one race_asian                                                                                                                  3112 non-null   int64
#  19  race_total population_one race_asian_asian indian                                                                                                     3112 non-null   int64
#  20  race_total population_one race_asian_chinese                                                                                                          3112 non-null   int64
#  21  race_total population_one race_asian_filipino                                                                                                         3112 non-null   int64
#  22  race_total population_one race_asian_japanese                                                                                                         3112 non-null   int64
#  23  race_total population_one race_asian_korean                                                                                                           3112 non-null   int64
#  24  race_total population_one race_asian_vietnamese                                                                                                       3112 non-null   int64
#  25  race_total population_one race_asian_other asian                                                                                                      3112 non-null   int64
#  26  race_total population_one race_native hawaiian and other pacific islander                                                                             3112 non-null   int64
#  27  race_total population_one race_native hawaiian and other pacific islander_native hawaiian                                                             3112 non-null   int64
#  28  race_total population_one race_native hawaiian and other pacific islander_guamanian or chamorro                                                       3112 non-null   int64
#  29  race_total population_one race_native hawaiian and other pacific islander_samoan                                                                      3112 non-null   int64
#  30  race_total population_one race_native hawaiian and other pacific islander_other pacific islander                                                      3112 non-null   int64
#  31  race_total population_one race_some other race                                                                                                        3112 non-null   int64
#  32  race_total population_two or more races_1                                                                                                             3112 non-null   int64
#  33  race_total population_two or more races_white and black or african american                                                                           3112 non-null   int64
#  34  race_total population_two or more races_white and american indian and alaska native                                                                   3112 non-null   int64
#  35  race_total population_two or more races_white and asian                                                                                               3112 non-null   int64
#  36  race_total population_two or more races_black or african american and american indian and alaska native                                               3112 non-null   int64
#  37  race alone or in combination with one or more other races_total population                                                                            3112 non-null   int64
#  38  race alone or in combination with one or more other races_total population_white                                                                      3112 non-null   int64
#  39  race alone or in combination with one or more other races_total population_black or african american                                                  3112 non-null   int64
#  40  race alone or in combination with one or more other races_total population_american indian and alaska native                                          3112 non-null   int64
#  41  race alone or in combination with one or more other races_total population_asian                                                                      3112 non-null   int64
#  42  race alone or in combination with one or more other races_total population_native hawaiian and other pacific islander                                 3112 non-null   int64
#  43  race alone or in combination with one or more other races_total population_some other race                                                            3112 non-null   int64
#  44  hispanic or latino and race_total population                                                                                                          3112 non-null   int64
#  45  hispanic or latino and race_total population_hispanic or latino (of any race)                                                                         3112 non-null   int64
#  46  hispanic or latino and race_total population_hispanic or latino (of any race)_mexican                                                                 3112 non-null   int64
#  47  hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican                                                            3112 non-null   int64
#  48  hispanic or latino and race_total population_hispanic or latino (of any race)_cuban                                                                   3112 non-null   int64
#  49  hispanic or latino and race_total population_hispanic or latino (of any race)_other hispanic or latino                                                3112 non-null   int64
#  50  hispanic or latino and race_total population_not hispanic or latino                                                                                   3112 non-null   int64
#  51  hispanic or latino and race_total population_not hispanic or latino_white alone                                                                       3112 non-null   int64
#  52  hispanic or latino and race_total population_not hispanic or latino_black or african american alone                                                   3112 non-null   int64
#  53  hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone                                           3112 non-null   int64
#  54  hispanic or latino and race_total population_not hispanic or latino_asian alone                                                                       3112 non-null   int64
#  55  hispanic or latino and race_total population_not hispanic or latino_native hawaiian and other pacific islander alone                                  3112 non-null   int64
#  56  hispanic or latino and race_total population_not hispanic or latino_some other race alone                                                             3112 non-null   int64
#  57  hispanic or latino and race_total population_not hispanic or latino_two or more races                                                                 3112 non-null   int64
#  58  hispanic or latino and race_total population_not hispanic or latino_two or more races_two races including some other race                             3112 non-null   int64
#  59  hispanic or latino and race_total population_not hispanic or latino_two or more races_two races excluding some other race -  and three or more races  3112 non-null   int64
#  60  total housing units                                                                                                                                   3112 non-null   int64
#  61  citizen -  voting age population_citizen -  18 and over population                                                                                    3112 non-null   int64
#  62  citizen -  voting age population_citizen -  18 and over population_male                                                                               3112 non-null   int64
#  63  citizen -  voting age population_citizen -  18 and over population_female                                                                             3112 non-null   int64
#  64  sex and age_total population                                                                                                                          3112 non-null   int64
#  65  sex and age_total population_male                                                                                                                     3112 non-null   int64
#  66  sex and age_total population_female                                                                                                                   3112 non-null   int64
#  67  sex and age_total population_sex ratio (males per 100 females)                                                                                        3112 non-null   float64
#  68  sex and age_total population_under 5 years                                                                                                            3112 non-null   int64
#  69  sex and age_total population_5 to 9 years                                                                                                             3112 non-null   int64
#  70  sex and age_total population_10 to 14 years                                                                                                           3112 non-null   int64
#  71  sex and age_total population_15 to 19 years                                                                                                           3112 non-null   int64
#  72  sex and age_total population_20 to 24 years                                                                                                           3112 non-null   int64
#  73  sex and age_total population_25 to 34 years                                                                                                           3112 non-null   int64
#  74  sex and age_total population_35 to 44 years                                                                                                           3112 non-null   int64
#  75  sex and age_total population_45 to 54 years                                                                                                           3112 non-null   int64
#  76  sex and age_total population_55 to 59 years                                                                                                           3112 non-null   int64
#  77  sex and age_total population_60 to 64 years                                                                                                           3112 non-null   int64
#  78  sex and age_total population_65 to 74 years                                                                                                           3112 non-null   int64
#  79  sex and age_total population_75 to 84 years                                                                                                           3112 non-null   int64
#  80  sex and age_total population_85 years and over                                                                                                        3112 non-null   int64
#  81  sex and age_total population_median age (years)                                                                                                       3112 non-null   float64
#  82  sex and age_total population_under 18 years                                                                                                           3112 non-null   int64
#  83  sex and age_total population_16 years and over                                                                                                        3112 non-null   int64
#  84  sex and age_total population_18 years and over                                                                                                        3112 non-null   int64
#  85  sex and age_total population_21 years and over                                                                                                        3112 non-null   int64
#  86  sex and age_total population_62 years and over                                                                                                        3112 non-null   int64
#  87  sex and age_total population_65 years and over                                                                                                        3112 non-null   int64
#  88  sex and age_total population_18 years and over_1                                                                                                      3112 non-null   int64
#  89  sex and age_total population_18 years and over_male                                                                                                   3112 non-null   int64
#  90  sex and age_total population_18 years and over_female                                                                                                 3112 non-null   int64
#  91  sex and age_total population_18 years and over_sex ratio (males per 100 females)                                                                      3112 non-null   float64
#  92  sex and age_total population_65 years and over_1                                                                                                      3112 non-null   int64
#  93  sex and age_total population_65 years and over_male                                                                                                   3112 non-null   int64
#  94  sex and age_total population_65 years and over_female                                                                                                 3112 non-null   int64
# dtypes: float64(4), int64(89), object(2)
# memory usage: 2.3+ MB

# %%
clean.select_dtypes(include = "object").head()
# Out:
#            County    State
# 0  Autauga County  Alabama
# 1  Baldwin County  Alabama
# 2  Barbour County  Alabama
# 3     Bibb County  Alabama
# 4   Blount County  Alabama

# %% [markdown]
# From https://www.mayoclinic.org/diseases-conditions/diabetes/symptoms-causes/syc-20371444
#
# Risk factors for prediabetes and type 2 diabetes
#
# Researchers don't fully understand why some people develop prediabetes and type 2 diabetes and others don't. It's clear that certain factors increase the risk, however, including:
#
# Weight. The more fatty tissue you have, the more resistant your cells become to insulin.
# Inactivity. The less active you are, the greater your risk. Physical activity helps you control your weight, uses up glucose as energy and makes your cells more sensitive to insulin.
#
# Family history. Your risk increases if a parent or sibling has type 2 diabetes.
#
# Race or ethnicity. Although it's unclear why, certain people — including Black, Hispanic, American Indian and Asian American people — are at higher risk.
#
# Age. Your risk increases as you get older. This may be because you tend to exercise less, lose muscle mass and gain weight as you age. But type 2 diabetes is also increasing among children, adolescents and younger adults.
#
# Gestational diabetes. If you developed gestational diabetes when you were pregnant, your risk of developing prediabetes and type 2 diabetes later increases. If you gave birth to a baby weighing more than 9 pounds (4 kilograms), you're also at risk of type 2 diabetes.
#
# Polycystic ovary syndrome. For women, having polycystic ovary syndrome — a common condition characterized by irregular menstrual periods, excess hair growth and obesity — increases the risk of diabetes.
# High blood pressure. Having blood pressure over 140/90 millimeters of mercury (mm Hg) is linked to an increased risk of type 2 diabetes.
#
# Abnormal cholesterol and triglyceride levels. If you have low levels of high-density lipoprotein (HDL), or "good," cholesterol, your risk of type 2 diabetes is higher. Triglycerides are another type of fat carried in the blood. People with high levels of triglycerides have an increased risk of type 2 diabetes. Your doctor can let you know what your cholesterol and triglyceride levels are.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# # Graphs
# Y axis is always diabetes rates (diabetes number divided by total population) in these scatter plots.
#
# Looking at a few different potential relationships based on the Mayo clinic info (obesity, physical inactivity, age, and race/ethnicity).

# %%
plt.plot(clean.iloc[:,7], clean.Diabetes_Number/clean.iloc[:,64], 'o');
# just trying to see if population size itself is correlated w/ diabetes rates 
# (it's not lol)

# %%
plt.plot(clean.Obesity_Number.astype(int)/clean.iloc[:,64], clean.Diabetes_Number/clean.iloc[:,64], 'o');

# Seems like somewhat linear relationship between obesity rates and diabetes rates?

# %%
plt.plot(clean.Physical_Inactivity_Number/clean.iloc[:,64], clean.Diabetes_Number/clean.iloc[:,64], 'o');
# Relationship between physical inactivity rates and diabetes rates
# Somewhat linear too!

# %%
plt.plot(clean.iloc[:,81], clean.Diabetes_Number/clean.iloc[:,64], 'o');
# looks like median age doesn't say too much

# %%
plt.plot(clean.iloc[:,87]/clean.iloc[:,64], clean.Diabetes_Number/clean.iloc[:,64], 'o');
# proportion of population 65 yrs and older
# vaguely linear...

# %%
whiteproportion = clean.iloc[:,11]/clean.iloc[:,7]

plt.plot((1 - whiteproportion), clean.Diabetes_Number/clean.iloc[:,64], 'o');

# the proportion of the county population that is NOT monoracial white 
# doesn't seem to be strongly correlated

# %%
hispanicproportion = clean.iloc[:,45]/clean.iloc[:,44]
plt.plot(hispanicproportion, clean.Diabetes_Number/clean.iloc[:,44], 'o');
# proportion of county population that is hispanic (of any race)

# %%
plt.plot(clean.iloc[:,6], clean.Diabetes_Number/clean.iloc[:,44], 'o');
# sex ratio (males per 100 females), above 65
# also doesn't seem to be strongly correlated

# %% [markdown]
# # Prepare to fit models

# %%
from sklearn import preprocessing

# %%
# normalizing all the data 
# (pulled from https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame)

clean2 = clean.drop(["County", "CountyFIPS", "Diabetes_Number"], 1) # dropping county labels and the dependent variable
clean2 = pd.get_dummies(clean2) # dummifying the state feature 

# normalizing features 

#MONICA TO ADD 
min_max_scaler = preprocessing.MinMaxScaler()
##

X = pd.DataFrame(min_max_scaler.fit_transform(clean2), columns=clean2.columns, index=clean2.index) 




    
# making y    
y = clean.Diabetes_Number

# %%
# double check data 

X.info(verbose = True)
y
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3112 entries, 0 to 3219
# Data columns (total 142 columns):
#  #   Column                                                                                                                                                Dtype
# ---  ------                                                                                                                                                -----
#  0   Obesity_Number                                                                                                                                        float64
#  1   Physical_Inactivity_Number                                                                                                                            float64
#  2   sex and age_total population_65 years and over_sex ratio (males per 100 females)                                                                      float64
#  3   race_total population                                                                                                                                 float64
#  4   race_total population_one race                                                                                                                        float64
#  5   race_total population_two or more races                                                                                                               float64
#  6   race_total population_one race_1                                                                                                                      float64
#  7   race_total population_one race_white                                                                                                                  float64
#  8   race_total population_one race_black or african american                                                                                              float64
#  9   race_total population_one race_american indian and alaska native                                                                                      float64
#  10  race_total population_one race_american indian and alaska native_cherokee tribal grouping                                                             float64
#  11  race_total population_one race_american indian and alaska native_chippewa tribal grouping                                                             float64
#  12  race_total population_one race_american indian and alaska native_navajo tribal grouping                                                               float64
#  13  race_total population_one race_american indian and alaska native_sioux tribal grouping                                                                float64
#  14  race_total population_one race_asian                                                                                                                  float64
#  15  race_total population_one race_asian_asian indian                                                                                                     float64
#  16  race_total population_one race_asian_chinese                                                                                                          float64
#  17  race_total population_one race_asian_filipino                                                                                                         float64
#  18  race_total population_one race_asian_japanese                                                                                                         float64
#  19  race_total population_one race_asian_korean                                                                                                           float64
#  20  race_total population_one race_asian_vietnamese                                                                                                       float64
#  21  race_total population_one race_asian_other asian                                                                                                      float64
#  22  race_total population_one race_native hawaiian and other pacific islander                                                                             float64
#  23  race_total population_one race_native hawaiian and other pacific islander_native hawaiian                                                             float64
#  24  race_total population_one race_native hawaiian and other pacific islander_guamanian or chamorro                                                       float64
#  25  race_total population_one race_native hawaiian and other pacific islander_samoan                                                                      float64
#  26  race_total population_one race_native hawaiian and other pacific islander_other pacific islander                                                      float64
#  27  race_total population_one race_some other race                                                                                                        float64
#  28  race_total population_two or more races_1                                                                                                             float64
#  29  race_total population_two or more races_white and black or african american                                                                           float64
#  30  race_total population_two or more races_white and american indian and alaska native                                                                   float64
#  31  race_total population_two or more races_white and asian                                                                                               float64
#  32  race_total population_two or more races_black or african american and american indian and alaska native                                               float64
#  33  race alone or in combination with one or more other races_total population                                                                            float64
#  34  race alone or in combination with one or more other races_total population_white                                                                      float64
#  35  race alone or in combination with one or more other races_total population_black or african american                                                  float64
#  36  race alone or in combination with one or more other races_total population_american indian and alaska native                                          float64
#  37  race alone or in combination with one or more other races_total population_asian                                                                      float64
#  38  race alone or in combination with one or more other races_total population_native hawaiian and other pacific islander                                 float64
#  39  race alone or in combination with one or more other races_total population_some other race                                                            float64
#  40  hispanic or latino and race_total population                                                                                                          float64
#  41  hispanic or latino and race_total population_hispanic or latino (of any race)                                                                         float64
#  42  hispanic or latino and race_total population_hispanic or latino (of any race)_mexican                                                                 float64
#  43  hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican                                                            float64
#  44  hispanic or latino and race_total population_hispanic or latino (of any race)_cuban                                                                   float64
#  45  hispanic or latino and race_total population_hispanic or latino (of any race)_other hispanic or latino                                                float64
#  46  hispanic or latino and race_total population_not hispanic or latino                                                                                   float64
#  47  hispanic or latino and race_total population_not hispanic or latino_white alone                                                                       float64
#  48  hispanic or latino and race_total population_not hispanic or latino_black or african american alone                                                   float64
#  49  hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone                                           float64
#  50  hispanic or latino and race_total population_not hispanic or latino_asian alone                                                                       float64
#  51  hispanic or latino and race_total population_not hispanic or latino_native hawaiian and other pacific islander alone                                  float64
#  52  hispanic or latino and race_total population_not hispanic or latino_some other race alone                                                             float64
#  53  hispanic or latino and race_total population_not hispanic or latino_two or more races                                                                 float64
#  54  hispanic or latino and race_total population_not hispanic or latino_two or more races_two races including some other race                             float64
#  55  hispanic or latino and race_total population_not hispanic or latino_two or more races_two races excluding some other race -  and three or more races  float64
#  56  total housing units                                                                                                                                   float64
#  57  citizen -  voting age population_citizen -  18 and over population                                                                                    float64
#  58  citizen -  voting age population_citizen -  18 and over population_male                                                                               float64
#  59  citizen -  voting age population_citizen -  18 and over population_female                                                                             float64
#  60  sex and age_total population                                                                                                                          float64
#  61  sex and age_total population_male                                                                                                                     float64
#  62  sex and age_total population_female                                                                                                                   float64
#  63  sex and age_total population_sex ratio (males per 100 females)                                                                                        float64
#  64  sex and age_total population_under 5 years                                                                                                            float64
#  65  sex and age_total population_5 to 9 years                                                                                                             float64
#  66  sex and age_total population_10 to 14 years                                                                                                           float64
#  67  sex and age_total population_15 to 19 years                                                                                                           float64
#  68  sex and age_total population_20 to 24 years                                                                                                           float64
#  69  sex and age_total population_25 to 34 years                                                                                                           float64
#  70  sex and age_total population_35 to 44 years                                                                                                           float64
#  71  sex and age_total population_45 to 54 years                                                                                                           float64
#  72  sex and age_total population_55 to 59 years                                                                                                           float64
#  73  sex and age_total population_60 to 64 years                                                                                                           float64
#  74  sex and age_total population_65 to 74 years                                                                                                           float64
#  75  sex and age_total population_75 to 84 years                                                                                                           float64
#  76  sex and age_total population_85 years and over                                                                                                        float64
#  77  sex and age_total population_median age (years)                                                                                                       float64
#  78  sex and age_total population_under 18 years                                                                                                           float64
#  79  sex and age_total population_16 years and over                                                                                                        float64
#  80  sex and age_total population_18 years and over                                                                                                        float64
#  81  sex and age_total population_21 years and over                                                                                                        float64
#  82  sex and age_total population_62 years and over                                                                                                        float64
#  83  sex and age_total population_65 years and over                                                                                                        float64
#  84  sex and age_total population_18 years and over_1                                                                                                      float64
#  85  sex and age_total population_18 years and over_male                                                                                                   float64
#  86  sex and age_total population_18 years and over_female                                                                                                 float64
#  87  sex and age_total population_18 years and over_sex ratio (males per 100 females)                                                                      float64
#  88  sex and age_total population_65 years and over_1                                                                                                      float64
#  89  sex and age_total population_65 years and over_male                                                                                                   float64
#  90  sex and age_total population_65 years and over_female                                                                                                 float64
#  91  State_Alabama                                                                                                                                         float64
#  92  State_Alaska                                                                                                                                          float64
#  93  State_Arizona                                                                                                                                         float64
#  94  State_Arkansas                                                                                                                                        float64
#  95  State_California                                                                                                                                      float64
#  96  State_Colorado                                                                                                                                        float64
#  97  State_Connecticut                                                                                                                                     float64
#  98  State_Delaware                                                                                                                                        float64
#  99  State_District of Columbia                                                                                                                            float64
#  100 State_Florida                                                                                                                                         float64
#  101 State_Georgia                                                                                                                                         float64
#  102 State_Hawaii                                                                                                                                          float64
#  103 State_Idaho                                                                                                                                           float64
#  104 State_Illinois                                                                                                                                        float64
#  105 State_Indiana                                                                                                                                         float64
#  106 State_Iowa                                                                                                                                            float64
#  107 State_Kansas                                                                                                                                          float64
#  108 State_Kentucky                                                                                                                                        float64
#  109 State_Louisiana                                                                                                                                       float64
#  110 State_Maine                                                                                                                                           float64
#  111 State_Maryland                                                                                                                                        float64
#  112 State_Massachusetts                                                                                                                                   float64
#  113 State_Michigan                                                                                                                                        float64
#  114 State_Minnesota                                                                                                                                       float64
#  115 State_Mississippi                                                                                                                                     float64
#  116 State_Missouri                                                                                                                                        float64
#  117 State_Montana                                                                                                                                         float64
#  118 State_Nebraska                                                                                                                                        float64
#  119 State_Nevada                                                                                                                                          float64
#  120 State_New Hampshire                                                                                                                                   float64
#  121 State_New Jersey                                                                                                                                      float64
#  122 State_New Mexico                                                                                                                                      float64
#  123 State_New York                                                                                                                                        float64
#  124 State_North Carolina                                                                                                                                  float64
#  125 State_North Dakota                                                                                                                                    float64
#  126 State_Ohio                                                                                                                                            float64
#  127 State_Oklahoma                                                                                                                                        float64
#  128 State_Oregon                                                                                                                                          float64
#  129 State_Pennsylvania                                                                                                                                    float64
#  130 State_Rhode Island                                                                                                                                    float64
#  131 State_South Carolina                                                                                                                                  float64
#  132 State_South Dakota                                                                                                                                    float64
#  133 State_Tennessee                                                                                                                                       float64
#  134 State_Texas                                                                                                                                           float64
#  135 State_Utah                                                                                                                                            float64
#  136 State_Vermont                                                                                                                                         float64
#  137 State_Virginia                                                                                                                                        float64
#  138 State_Washington                                                                                                                                      float64
#  139 State_West Virginia                                                                                                                                   float64
#  140 State_Wisconsin                                                                                                                                       float64
#  141 State_Wyoming                                                                                                                                         float64
# dtypes: float64(142)
# memory usage: 3.4 MB
# 0        5178
# 1       16707
# 2        3400
# 3        2371
# 4        6282
#         ...
# 3215     2560
# 3216      439
# 3217     1440
# 3218      637
# 3219      601
# Name: Diabetes_Number, Length: 3112, dtype: int64

# %% [markdown]
# ## 3.2 Partition Data

# %%
import numpy as np
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# %%
# set the random seed
np.random.seed(10)

# split the data into training and test data
# train_test_split returns 4 values: X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.80)

# %%
# then split the training data for cross validation (actual training data and then cross-validation set)
# Returns 4 values: X_train, X_validate, y_train, y_validate

X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train, train_size=0.75)

# %% [markdown]
# # 3.3 Feature Selection

# %%
import matplotlib.pyplot as plt
import statsmodels.graphics.api as smg

# %%
#from https://www.statsmodels.org/stable/generated/statsmodels.graphics.correlation.plot_corr.html#statsmodels.graphics.correlation.plot_corr
# checking pairwise correlation for all the Xs 
# seems to be that a lot of the county population features are highly correlated 
# and all the less correlated features are probably the dummies for each of the states

corr_matrix = np.corrcoef(X_train.T)
smg.plot_corr(corr_matrix)
plt.show()

# %%
# checking correlation with Obesity Number
# not sure what is too high to drop... I think if we are only concerned w/ prediction correlation doesn't matter, 
# but anything more than 0.95 correlation seems way too high 

# can play around with this to see what variables drop out!

corrs = corr_matrix[0,:] < 0.95

corrs[0] = True

print(X_train.columns[~corrs]) # these are the variables to be dropped (bc they have almost perfect correlation)

# makes sense that Physical_Inactivity will be dropped
# makes sense that a lot that are being dropped are measures of size of whole population
    # e.g., all total population counts, total monoracial population, total citizens
# Out:
# Index(['Physical_Inactivity_Number', 'race_total population',
#        'race_total population_one race', 'race_total population_one race_1',
#        'race_total population_one race_white',
#        'race alone or in combination with one or more other races_total population',
#        'race alone or in combination with one or more other races_total population_white',
#        'hispanic or latino and race_total population',
#        'hispanic or latino and race_total population_not hispanic or latino',
#        'total housing units',
#        'citizen -  voting age population_citizen -  18 and over population',
#        'citizen -  voting age population_citizen -  18 and over population_male',
#        'citizen -  voting age population_citizen -  18 and over population_female',
#        'sex and age_total population', 'sex and age_total population_male',
#        'sex and age_total population_female',
#        'sex and age_total population_under 5 years',
#        'sex and age_total population_5 to 9 years',
#        'sex and age_total population_10 to 14 years',
#        'sex and age_total population_15 to 19 years',
#        'sex and age_total population_20 to 24 years',
#        'sex and age_total population_25 to 34 years',
#        'sex and age_total population_35 to 44 years',
#        'sex and age_total population_45 to 54 years',
#        'sex and age_total population_55 to 59 years',
#        'sex and age_total population_60 to 64 years',
#        'sex and age_total population_65 to 74 years',
#        'sex and age_total population_75 to 84 years',
#        'sex and age_total population_85 years and over',
#        'sex and age_total population_under 18 years',
#        'sex and age_total population_16 years and over',
#        'sex and age_total population_18 years and over',
#        'sex and age_total population_21 years and over',
#        'sex and age_total population_62 years and over',
#        'sex and age_total population_65 years and over',
#        'sex and age_total population_18 years and over_1',
#        'sex and age_total population_18 years and over_male',
#        'sex and age_total population_18 years and over_female',
#        'sex and age_total population_65 years and over_1',
#        'sex and age_total population_65 years and over_male',
#        'sex and age_total population_65 years and over_female'],
#       dtype='object')

# %%
# taking out all features that have a correlation higher than 0.95, 101 features remain

X_train = X_train[X_train.columns[corrs]]
X_validate = X_validate[X_validate.columns[corrs]]
X_train.info(verbose = True) 

# makes sense that a lot of the subgroup features are left (e.g., total Black population) 
# and also all(?) the state dummy variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1866 entries, 3000 to 1016
# Data columns (total 101 columns):
#  #   Column                                                                                                                                                Dtype
# ---  ------                                                                                                                                                -----
#  0   Obesity_Number                                                                                                                                        float64
#  1   sex and age_total population_65 years and over_sex ratio (males per 100 females)                                                                      float64
#  2   race_total population_two or more races                                                                                                               float64
#  3   race_total population_one race_black or african american                                                                                              float64
#  4   race_total population_one race_american indian and alaska native                                                                                      float64
#  5   race_total population_one race_american indian and alaska native_cherokee tribal grouping                                                             float64
#  6   race_total population_one race_american indian and alaska native_chippewa tribal grouping                                                             float64
#  7   race_total population_one race_american indian and alaska native_navajo tribal grouping                                                               float64
#  8   race_total population_one race_american indian and alaska native_sioux tribal grouping                                                                float64
#  9   race_total population_one race_asian                                                                                                                  float64
#  10  race_total population_one race_asian_asian indian                                                                                                     float64
#  11  race_total population_one race_asian_chinese                                                                                                          float64
#  12  race_total population_one race_asian_filipino                                                                                                         float64
#  13  race_total population_one race_asian_japanese                                                                                                         float64
#  14  race_total population_one race_asian_korean                                                                                                           float64
#  15  race_total population_one race_asian_vietnamese                                                                                                       float64
#  16  race_total population_one race_asian_other asian                                                                                                      float64
#  17  race_total population_one race_native hawaiian and other pacific islander                                                                             float64
#  18  race_total population_one race_native hawaiian and other pacific islander_native hawaiian                                                             float64
#  19  race_total population_one race_native hawaiian and other pacific islander_guamanian or chamorro                                                       float64
#  20  race_total population_one race_native hawaiian and other pacific islander_samoan                                                                      float64
#  21  race_total population_one race_native hawaiian and other pacific islander_other pacific islander                                                      float64
#  22  race_total population_one race_some other race                                                                                                        float64
#  23  race_total population_two or more races_1                                                                                                             float64
#  24  race_total population_two or more races_white and black or african american                                                                           float64
#  25  race_total population_two or more races_white and american indian and alaska native                                                                   float64
#  26  race_total population_two or more races_white and asian                                                                                               float64
#  27  race_total population_two or more races_black or african american and american indian and alaska native                                               float64
#  28  race alone or in combination with one or more other races_total population_black or african american                                                  float64
#  29  race alone or in combination with one or more other races_total population_american indian and alaska native                                          float64
#  30  race alone or in combination with one or more other races_total population_asian                                                                      float64
#  31  race alone or in combination with one or more other races_total population_native hawaiian and other pacific islander                                 float64
#  32  race alone or in combination with one or more other races_total population_some other race                                                            float64
#  33  hispanic or latino and race_total population_hispanic or latino (of any race)                                                                         float64
#  34  hispanic or latino and race_total population_hispanic or latino (of any race)_mexican                                                                 float64
#  35  hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican                                                            float64
#  36  hispanic or latino and race_total population_hispanic or latino (of any race)_cuban                                                                   float64
#  37  hispanic or latino and race_total population_hispanic or latino (of any race)_other hispanic or latino                                                float64
#  38  hispanic or latino and race_total population_not hispanic or latino_white alone                                                                       float64
#  39  hispanic or latino and race_total population_not hispanic or latino_black or african american alone                                                   float64
#  40  hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone                                           float64
#  41  hispanic or latino and race_total population_not hispanic or latino_asian alone                                                                       float64
#  42  hispanic or latino and race_total population_not hispanic or latino_native hawaiian and other pacific islander alone                                  float64
#  43  hispanic or latino and race_total population_not hispanic or latino_some other race alone                                                             float64
#  44  hispanic or latino and race_total population_not hispanic or latino_two or more races                                                                 float64
#  45  hispanic or latino and race_total population_not hispanic or latino_two or more races_two races including some other race                             float64
#  46  hispanic or latino and race_total population_not hispanic or latino_two or more races_two races excluding some other race -  and three or more races  float64
#  47  sex and age_total population_sex ratio (males per 100 females)                                                                                        float64
#  48  sex and age_total population_median age (years)                                                                                                       float64
#  49  sex and age_total population_18 years and over_sex ratio (males per 100 females)                                                                      float64
#  50  State_Alabama                                                                                                                                         float64
#  51  State_Alaska                                                                                                                                          float64
#  52  State_Arizona                                                                                                                                         float64
#  53  State_Arkansas                                                                                                                                        float64
#  54  State_California                                                                                                                                      float64
#  55  State_Colorado                                                                                                                                        float64
#  56  State_Connecticut                                                                                                                                     float64
#  57  State_Delaware                                                                                                                                        float64
#  58  State_District of Columbia                                                                                                                            float64
#  59  State_Florida                                                                                                                                         float64
#  60  State_Georgia                                                                                                                                         float64
#  61  State_Hawaii                                                                                                                                          float64
#  62  State_Idaho                                                                                                                                           float64
#  63  State_Illinois                                                                                                                                        float64
#  64  State_Indiana                                                                                                                                         float64
#  65  State_Iowa                                                                                                                                            float64
#  66  State_Kansas                                                                                                                                          float64
#  67  State_Kentucky                                                                                                                                        float64
#  68  State_Louisiana                                                                                                                                       float64
#  69  State_Maine                                                                                                                                           float64
#  70  State_Maryland                                                                                                                                        float64
#  71  State_Massachusetts                                                                                                                                   float64
#  72  State_Michigan                                                                                                                                        float64
#  73  State_Minnesota                                                                                                                                       float64
#  74  State_Mississippi                                                                                                                                     float64
#  75  State_Missouri                                                                                                                                        float64
#  76  State_Montana                                                                                                                                         float64
#  77  State_Nebraska                                                                                                                                        float64
#  78  State_Nevada                                                                                                                                          float64
#  79  State_New Hampshire                                                                                                                                   float64
#  80  State_New Jersey                                                                                                                                      float64
#  81  State_New Mexico                                                                                                                                      float64
#  82  State_New York                                                                                                                                        float64
#  83  State_North Carolina                                                                                                                                  float64
#  84  State_North Dakota                                                                                                                                    float64
#  85  State_Ohio                                                                                                                                            float64
#  86  State_Oklahoma                                                                                                                                        float64
#  87  State_Oregon                                                                                                                                          float64
#  88  State_Pennsylvania                                                                                                                                    float64
#  89  State_Rhode Island                                                                                                                                    float64
#  90  State_South Carolina                                                                                                                                  float64
#  91  State_South Dakota                                                                                                                                    float64
#  92  State_Tennessee                                                                                                                                       float64
#  93  State_Texas                                                                                                                                           float64
#  94  State_Utah                                                                                                                                            float64
#  95  State_Vermont                                                                                                                                         float64
#  96  State_Virginia                                                                                                                                        float64
#  97  State_Washington                                                                                                                                      float64
#  98  State_West Virginia                                                                                                                                   float64
#  99  State_Wisconsin                                                                                                                                       float64
#  100 State_Wyoming                                                                                                                                         float64
# dtypes: float64(101)
# memory usage: 1.5 MB

# %% [markdown]
# # 4 Train Models

# %% [markdown]
# ## Just trying out a normal OLS

# %%
# just gonna run a normal OLS and see what happens

lin_reg = LinearRegression(normalize=True)

# fit the model
lin_model = lin_reg.fit(X_train, y_train)

# %%
print(lin_model.coef_)
print(lin_model.intercept_)
# Out:
# [ 4.47570251e+05 -2.72613178e+03 -1.27830357e+06 -5.50138667e+06
#  -1.44500941e+05  3.57290266e+03 -8.52461874e+00  6.61574748e+02
#   6.65765779e+02  2.25082891e+05  8.32811571e+04  3.17235972e+05
#   2.61997348e+05  1.15301940e+05  2.04232914e+05  1.65852866e+05
#   8.22376626e+04 -1.65773043e+05 -2.93019430e+05  1.07065401e+04
#  -1.97952512e+04 -5.64766801e+04 -1.28883290e+07 -1.27830357e+06
#   1.37617569e+05  2.29353306e+05  4.64937711e+05  8.53462258e+03
#   5.13846243e+06  2.65427457e+05  1.23780868e+06  1.65740468e+06
#   1.35444321e+07  2.42514383e+04  2.37842345e+04  3.52558977e+03
#   8.68840154e+01  2.50520513e+04  6.01977122e+04  5.93208435e+05
#   9.27790253e+03 -2.15646715e+06 -3.39826690e+05  1.76686316e+04
#  -1.98298401e+03 -7.73954169e+03 -1.61855453e+03 -8.66475065e+02
#   2.79798724e+03 -8.24117058e+02  5.69628653e+02  3.50995238e+02
#   3.51573496e+01  1.90226084e+02  1.86025745e+03 -8.84660446e+02
#  -3.09749712e+03  8.95551366e+02 -1.77831670e+03  2.96169569e+03
#   1.24127808e+02  4.18566902e+04 -5.47259437e+01 -5.17232112e+02
#  -8.21825780e+01 -6.04344955e+02 -3.62318589e+02 -2.81317967e+01
#   5.74124277e+01 -1.99490828e+02 -5.74437412e+02 -4.06487805e+03
#  -3.13770826e+02 -9.56817577e+02  2.20640139e+01 -1.12261118e+02
#  -3.89217981e+02 -5.63101653e+02  1.57439507e+02 -7.47190798e+02
#  -1.72938428e+03  4.33920786e+02 -3.05938790e+02 -2.05017216e+02
#  -4.61680738e+02  4.60072134e+02 -2.02111469e+02  4.71326492e+02
#  -1.36424328e+02 -3.40081196e+03  7.14875794e+02 -3.61540961e+02
#   3.04927929e+01  5.56883998e+01 -2.06123518e+02 -6.23413416e+02
#  -1.89138394e+02  4.34866253e+02  1.00450782e+02 -9.36868259e+02
#  -1.58128890e+02]
# -33.35740134261323

# %%
# Create a dataframe with the coefficient and feature names
# this is unintelligible with 101 variables lmao

lin_reg_data = pd.DataFrame([lin_model.coef_, X_train.columns]).T
lin_reg_data.columns = ['Coefficient', 'Feature']
# Plot
ax = sns.barplot(x="Coefficient", y="Feature", data=lin_reg_data)
ax.set_title("OLS Coefficients")
plt.savefig('plot.png', dpi=300)

# some of these coefficients seem high since y is normalized, but maybe not an issue bc prediction...

# %%
# predict the number of diabetes, using OLS parameters
lin_pred = lin_model.predict(X_validate)

# plot the residuals on a scatter plot
plt.scatter(lin_pred, y_validate)
plt.title('Linear Model (OLS) Predicted v. Actual')
plt.xlabel('actual value')
plt.ylabel('predicted value')
plt.show()


# this looks decent !! but can maybe do better w/ lasso?

# %%
def rmse(pred, actual):
    return pow(np.mean(pow((pred-actual), 2)), 0.5)

# %%
rmse(lin_pred, y_validate)
# Out:
# 3332.950219208833

# %% [markdown]
# ## Trying out Ridge

# %%
# make and fit a Ridge regression model
ridge_reg = Ridge() 
ridge_model = ridge_reg.fit(X_train, y_train)
ridge_reg_data = pd.DataFrame([ridge_model.coef_, X.columns]).T
ridge_reg_data.columns = ['Coefficient', 'Feature']

# %%
# plot the coefficients in the ridge model
figure = plt.figure()
sns.barplot(x="Coefficient", y="Feature", data=ridge_reg_data).set_title("Ridge Coefficients")
# Out:
# Text(0.5, 1.0, 'Ridge Coefficients')

# %%
sns.barplot(x="Coefficient", y="Feature", data=lin_reg_data).set_title("OLS Coefficients")
plt.show()

# %%
# use the model to make predictions
ridge_pred = ridge_model.predict(X_validate)

# plot the predictions
plt.scatter(y_validate, ridge_pred)
plt.title('Ridge Model')
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.show()

# %%
# calculate the rmse for the Ridge model
rmse(ridge_pred, y_validate)
# Out:
# 3573.898238978838

# %% [markdown]
# ## Trying out lasso

# %%
# create and fit the model
lasso_reg = Lasso(max_iter=10000)  

lasso_model = lasso_reg.fit(X_train, y_train)
lasso_reg_data = pd.DataFrame([lasso_model.coef_, X.columns]).T
lasso_reg_data.columns = ['Coefficient', 'Feature']

# %%
figure = plt.figure()
figure.subplots_adjust(wspace = .5, hspace=.5)
sns.barplot(x="Coefficient", y="Feature", data=ridge_reg_data).set_title("Ridge Coefficients")
# Out:
# Text(0.5, 1.0, 'Ridge Coefficients')

# %%
sns.barplot(x="Coefficient", y="Feature", data=lasso_reg_data).set_title("LASSO Coefficients")
plt.show()

# %%
# use the model to make predictions
lasso_pred = lasso_model.predict(X_validate)

# plot the predictions
plt.scatter(y_validate, lasso_pred)
plt.title('LASSO Model')
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.show()

# %%
# calculate the rmse for the LASSO model
rmse(lasso_pred, y_validate)

#LASSO looks like our winner, winner, chicken dinner!
# Out:
# 3008.87684911976

# %% [markdown]
# ## 5. Validate and Refine Models

# %%
#5.1 Think we did this part already above and found that LASSO is the best model using the smallest RMSE?

# %%
#5.2 Feature Selection
# I don't know if this is the right code for Feature Selection
#I just copied what was in the Regression jupyter notebook from class for hyperparameter searching lol
param_grid = {'alpha': np.arange(.1, 1, .1),
               'normalize': ['True', 'False'],
             'fit_intercept': ['True', 'False'],
             'selection': ['cyclic', 'random']}

lasso_grid_reg = GridSearchCV(lasso_reg, param_grid, cv=3, iid=False)
lasso_grid_reg.fit(X_train, y_train)

best_index = np.argmax(lasso_grid_reg.cv_results_["mean_test_score"])
best_lasso_pred = lasso_grid_reg.best_estimator_.predict(X_validate)

print(lasso_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(lasso_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', lasso_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_lasso_pred, y_validate))
# Out:
# {'alpha': 0.9, 'fit_intercept': 'True', 'normalize': 'True', 'selection': 'cyclic'}
# Best CV R^2: 0.8889059213912717
# Validation R^2: 0.9639886892291555
# Validation RMSE 2990.4366511714748
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning

# %%
# Best model

best_pred = lasso_grid_reg.best_estimator_.predict(X_test)
print('Best CV R^2:', max(lasso_grid_reg.cv_results_["mean_test_score"]))
print('Test R^2:', lasso_grid_reg.score(X_test, y_test))
print('Test RMSE', rmse(best_pred, y_test))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-96-2648d7aba4cf> in <module>
#       1 # Best model
#       2
# ----> 3 best_pred = lasso_grid_reg.best_estimator_.predict(X_test)
#       4 print('Best CV R^2:', max(lasso_grid_reg.cv_results_["mean_test_score"]))
#       5 print('Test R^2:', lasso_grid_reg.score(X_test, y_test))
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in predict(self, X)
#     223             Returns predicted values.
#     224         """
# --> 225         return self._decision_function(X)
#     226
#     227     _preprocess_data = staticmethod(_preprocess_data)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py in _decision_function(self, X)
#     792                                    dense_output=True) + self.intercept_
#     793         else:
# --> 794             return super()._decision_function(X)
#     795
#     796
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_base.py in _decision_function(self, X)
#     207         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     208         return safe_sparse_dot(X, self.coef_.T,
# --> 209                                dense_output=True) + self.intercept_
#     210
#     211     def predict(self, X):
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     149             ret = np.dot(a, b)
#     150     else:
# --> 151         ret = a @ b
#     152
#     153     if (sparse.issparse(a) and sparse.issparse(b)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 101 is different from 142)
