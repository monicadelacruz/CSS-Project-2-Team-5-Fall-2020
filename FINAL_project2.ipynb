# %% [markdown]
# # Project 2
# ## Regression for Prediction Problems
# ### Monica, Jasmine, Paul

# %% [markdown]
# # 1. Importing data into Python

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Diabetes with Population Info by County 2017.csv") # importing data

# %%
data.head() #checking data out
# Out:
#            County    State  CountyFIPS Diabetes_Number Obesity_Number  \
# 0  Autauga County  Alabama        1001            5178          13489
# 1  Baldwin County  Alabama        1003           16707          48542
# 2  Barbour County  Alabama        1005            3400           8009
# 3     Bibb County  Alabama        1007            2371           6534
# 4   Blount County  Alabama        1009            6282          14227
#
#   Physical_Inactivity_Number  \
# 0                      12525
# 1                      40024
# 2                       5431
# 3                       5827
# 4                      14365
#
#   sex and age_total population_65 years and over_sex ratio (males per 100 females)  \
# 0                                               76.5
# 1                                               86.6
# 2                                               76.2
# 3                                               80.5
# 4                                               79.7
#
#    race_total population  race_total population_one race  \
# 0                  55200                           54170
# 1                 208107                          204535
# 2                  25782                           25429
# 3                  22527                           22340
# 4                  57645                           56710
#
#    race_total population_two or more races  ...  \
# 0                                     1030  ...
# 1                                     3572  ...
# 2                                      353  ...
# 3                                      187  ...
# 4                                      935  ...
#
#    sex and age_total population_21 years and over  \
# 0                                           39614
# 1                                          155502
# 2                                           19394
# 3                                           16864
# 4                                           42232
#
#    sex and age_total population_62 years and over  \
# 0                                            9403
# 1                                           49811
# 2                                            5658
# 3                                            4323
# 4                                           12400
#
#    sex and age_total population_65 years and over  \
# 0                                            8050
# 1                                           40665
# 2                                            4634
# 3                                            3661
# 4                                           10233
#
#    sex and age_total population_18 years and over_1  \
# 0                                             41831
# 1                                            162430
# 2                                             20346
# 3                                             17868
# 4                                             44177
#
#    sex and age_total population_18 years and over_male  \
# 0                                              20054
# 1                                              78104
# 2                                              10923
# 3                                               9578
# 4                                              21595
#
#    sex and age_total population_18 years and over_female  \
# 0                                              21777
# 1                                              84326
# 2                                               9423
# 3                                               8290
# 4                                              22582
#
#    sex and age_total population_18 years and over_sex ratio (males per 100 females)  \
# 0                                               92.1
# 1                                               92.6
# 2                                              115.9
# 3                                              115.5
# 4                                               95.6
#
#    sex and age_total population_65 years and over_1  \
# 0                                              8050
# 1                                             40665
# 2                                              4634
# 3                                              3661
# 4                                             10233
#
#    sex and age_total population_65 years and over_male  \
# 0                                               3488
# 1                                              18870
# 2                                               2004
# 3                                               1633
# 4                                               4540
#
#    sex and age_total population_65 years and over_female
# 0                                               4562
# 1                                              21795
# 2                                               2630
# 3                                               2028
# 4                                               5693
#
# [5 rows x 95 columns]

# %%
data.info(verbose = True) #checking data types and variables, 
                          # seems like Diabetes_Number (and some others) are not integers...
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3220 entries, 0 to 3219
# Data columns (total 95 columns):
# County                                                                                                                                                  3220 non-null object
# State                                                                                                                                                   3220 non-null object
# CountyFIPS                                                                                                                                              3220 non-null int64
# Diabetes_Number                                                                                                                                         3220 non-null object
# Obesity_Number                                                                                                                                          3220 non-null object
# Physical_Inactivity_Number                                                                                                                              3220 non-null object
# sex and age_total population_65 years and over_sex ratio (males per 100 females)                                                                        3220 non-null object
# race_total population                                                                                                                                   3220 non-null int64
# race_total population_one race                                                                                                                          3220 non-null int64
# race_total population_two or more races                                                                                                                 3220 non-null int64
# race_total population_one race_1                                                                                                                        3220 non-null int64
# race_total population_one race_white                                                                                                                    3220 non-null int64
# race_total population_one race_black or african american                                                                                                3220 non-null int64
# race_total population_one race_american indian and alaska native                                                                                        3220 non-null int64
# race_total population_one race_american indian and alaska native_cherokee tribal grouping                                                               3220 non-null int64
# race_total population_one race_american indian and alaska native_chippewa tribal grouping                                                               3220 non-null int64
# race_total population_one race_american indian and alaska native_navajo tribal grouping                                                                 3220 non-null int64
# race_total population_one race_american indian and alaska native_sioux tribal grouping                                                                  3220 non-null int64
# race_total population_one race_asian                                                                                                                    3220 non-null int64
# race_total population_one race_asian_asian indian                                                                                                       3220 non-null int64
# race_total population_one race_asian_chinese                                                                                                            3220 non-null int64
# race_total population_one race_asian_filipino                                                                                                           3220 non-null int64
# race_total population_one race_asian_japanese                                                                                                           3220 non-null int64
# race_total population_one race_asian_korean                                                                                                             3220 non-null int64
# race_total population_one race_asian_vietnamese                                                                                                         3220 non-null int64
# race_total population_one race_asian_other asian                                                                                                        3220 non-null int64
# race_total population_one race_native hawaiian and other pacific islander                                                                               3220 non-null int64
# race_total population_one race_native hawaiian and other pacific islander_native hawaiian                                                               3220 non-null int64
# race_total population_one race_native hawaiian and other pacific islander_guamanian or chamorro                                                         3220 non-null int64
# race_total population_one race_native hawaiian and other pacific islander_samoan                                                                        3220 non-null int64
# race_total population_one race_native hawaiian and other pacific islander_other pacific islander                                                        3220 non-null int64
# race_total population_one race_some other race                                                                                                          3220 non-null int64
# race_total population_two or more races_1                                                                                                               3220 non-null int64
# race_total population_two or more races_white and black or african american                                                                             3220 non-null int64
# race_total population_two or more races_white and american indian and alaska native                                                                     3220 non-null int64
# race_total population_two or more races_white and asian                                                                                                 3220 non-null int64
# race_total population_two or more races_black or african american and american indian and alaska native                                                 3220 non-null int64
# race alone or in combination with one or more other races_total population                                                                              3220 non-null int64
# race alone or in combination with one or more other races_total population_white                                                                        3220 non-null int64
# race alone or in combination with one or more other races_total population_black or african american                                                    3220 non-null int64
# race alone or in combination with one or more other races_total population_american indian and alaska native                                            3220 non-null int64
# race alone or in combination with one or more other races_total population_asian                                                                        3220 non-null int64
# race alone or in combination with one or more other races_total population_native hawaiian and other pacific islander                                   3220 non-null int64
# race alone or in combination with one or more other races_total population_some other race                                                              3220 non-null int64
# hispanic or latino and race_total population                                                                                                            3220 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)                                                                           3220 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)_mexican                                                                   3220 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican                                                              3220 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)_cuban                                                                     3220 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)_other hispanic or latino                                                  3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino                                                                                     3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_white alone                                                                         3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_black or african american alone                                                     3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone                                             3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_asian alone                                                                         3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_native hawaiian and other pacific islander alone                                    3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_some other race alone                                                               3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_two or more races                                                                   3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_two or more races_two races including some other race                               3220 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_two or more races_two races excluding some other race -  and three or more races    3220 non-null int64
# total housing units                                                                                                                                     3220 non-null int64
# citizen -  voting age population_citizen -  18 and over population                                                                                      3220 non-null int64
# citizen -  voting age population_citizen -  18 and over population_male                                                                                 3220 non-null int64
# citizen -  voting age population_citizen -  18 and over population_female                                                                               3220 non-null int64
# sex and age_total population                                                                                                                            3220 non-null int64
# sex and age_total population_male                                                                                                                       3220 non-null int64
# sex and age_total population_female                                                                                                                     3220 non-null int64
# sex and age_total population_sex ratio (males per 100 females)                                                                                          3220 non-null float64
# sex and age_total population_under 5 years                                                                                                              3220 non-null int64
# sex and age_total population_5 to 9 years                                                                                                               3220 non-null int64
# sex and age_total population_10 to 14 years                                                                                                             3220 non-null int64
# sex and age_total population_15 to 19 years                                                                                                             3220 non-null int64
# sex and age_total population_20 to 24 years                                                                                                             3220 non-null int64
# sex and age_total population_25 to 34 years                                                                                                             3220 non-null int64
# sex and age_total population_35 to 44 years                                                                                                             3220 non-null int64
# sex and age_total population_45 to 54 years                                                                                                             3220 non-null int64
# sex and age_total population_55 to 59 years                                                                                                             3220 non-null int64
# sex and age_total population_60 to 64 years                                                                                                             3220 non-null int64
# sex and age_total population_65 to 74 years                                                                                                             3220 non-null int64
# sex and age_total population_75 to 84 years                                                                                                             3220 non-null int64
# sex and age_total population_85 years and over                                                                                                          3220 non-null int64
# sex and age_total population_median age (years)                                                                                                         3220 non-null float64
# sex and age_total population_under 18 years                                                                                                             3220 non-null int64
# sex and age_total population_16 years and over                                                                                                          3220 non-null int64
# sex and age_total population_18 years and over                                                                                                          3220 non-null int64
# sex and age_total population_21 years and over                                                                                                          3220 non-null int64
# sex and age_total population_62 years and over                                                                                                          3220 non-null int64
# sex and age_total population_65 years and over                                                                                                          3220 non-null int64
# sex and age_total population_18 years and over_1                                                                                                        3220 non-null int64
# sex and age_total population_18 years and over_male                                                                                                     3220 non-null int64
# sex and age_total population_18 years and over_female                                                                                                   3220 non-null int64
# sex and age_total population_18 years and over_sex ratio (males per 100 females)                                                                        3220 non-null float64
# sex and age_total population_65 years and over_1                                                                                                        3220 non-null int64
# sex and age_total population_65 years and over_male                                                                                                     3220 non-null int64
# sex and age_total population_65 years and over_female                                                                                                   3220 non-null int64
# dtypes: float64(3), int64(86), object(6)
# memory usage: 2.3+ MB

# %%
#data.Diabetes_Number = data.Diabetes_Number.astype(int) # gets error bc of "No Data" value, not coercable to an integer

# %%
clean = data[data.Diabetes_Number != "Suppressed"] 
clean = clean[clean.Obesity_Number != "No Data"]
clean = clean[clean.iloc[:,6] != "-"]
# cleaning data to drop these rows bc we can't do anything with them

# %%
clean.iloc[:,3:6] = clean.iloc[:,3:6].astype(int) 
clean.iloc[:,6] = clean.iloc[:,6].astype(float)
# making all number columns into integer or float data types

# %%
clean.info(verbose = True) # double checking data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3112 entries, 0 to 3219
# Data columns (total 95 columns):
# County                                                                                                                                                  3112 non-null object
# State                                                                                                                                                   3112 non-null object
# CountyFIPS                                                                                                                                              3112 non-null int64
# Diabetes_Number                                                                                                                                         3112 non-null int64
# Obesity_Number                                                                                                                                          3112 non-null int64
# Physical_Inactivity_Number                                                                                                                              3112 non-null int64
# sex and age_total population_65 years and over_sex ratio (males per 100 females)                                                                        3112 non-null float64
# race_total population                                                                                                                                   3112 non-null int64
# race_total population_one race                                                                                                                          3112 non-null int64
# race_total population_two or more races                                                                                                                 3112 non-null int64
# race_total population_one race_1                                                                                                                        3112 non-null int64
# race_total population_one race_white                                                                                                                    3112 non-null int64
# race_total population_one race_black or african american                                                                                                3112 non-null int64
# race_total population_one race_american indian and alaska native                                                                                        3112 non-null int64
# race_total population_one race_american indian and alaska native_cherokee tribal grouping                                                               3112 non-null int64
# race_total population_one race_american indian and alaska native_chippewa tribal grouping                                                               3112 non-null int64
# race_total population_one race_american indian and alaska native_navajo tribal grouping                                                                 3112 non-null int64
# race_total population_one race_american indian and alaska native_sioux tribal grouping                                                                  3112 non-null int64
# race_total population_one race_asian                                                                                                                    3112 non-null int64
# race_total population_one race_asian_asian indian                                                                                                       3112 non-null int64
# race_total population_one race_asian_chinese                                                                                                            3112 non-null int64
# race_total population_one race_asian_filipino                                                                                                           3112 non-null int64
# race_total population_one race_asian_japanese                                                                                                           3112 non-null int64
# race_total population_one race_asian_korean                                                                                                             3112 non-null int64
# race_total population_one race_asian_vietnamese                                                                                                         3112 non-null int64
# race_total population_one race_asian_other asian                                                                                                        3112 non-null int64
# race_total population_one race_native hawaiian and other pacific islander                                                                               3112 non-null int64
# race_total population_one race_native hawaiian and other pacific islander_native hawaiian                                                               3112 non-null int64
# race_total population_one race_native hawaiian and other pacific islander_guamanian or chamorro                                                         3112 non-null int64
# race_total population_one race_native hawaiian and other pacific islander_samoan                                                                        3112 non-null int64
# race_total population_one race_native hawaiian and other pacific islander_other pacific islander                                                        3112 non-null int64
# race_total population_one race_some other race                                                                                                          3112 non-null int64
# race_total population_two or more races_1                                                                                                               3112 non-null int64
# race_total population_two or more races_white and black or african american                                                                             3112 non-null int64
# race_total population_two or more races_white and american indian and alaska native                                                                     3112 non-null int64
# race_total population_two or more races_white and asian                                                                                                 3112 non-null int64
# race_total population_two or more races_black or african american and american indian and alaska native                                                 3112 non-null int64
# race alone or in combination with one or more other races_total population                                                                              3112 non-null int64
# race alone or in combination with one or more other races_total population_white                                                                        3112 non-null int64
# race alone or in combination with one or more other races_total population_black or african american                                                    3112 non-null int64
# race alone or in combination with one or more other races_total population_american indian and alaska native                                            3112 non-null int64
# race alone or in combination with one or more other races_total population_asian                                                                        3112 non-null int64
# race alone or in combination with one or more other races_total population_native hawaiian and other pacific islander                                   3112 non-null int64
# race alone or in combination with one or more other races_total population_some other race                                                              3112 non-null int64
# hispanic or latino and race_total population                                                                                                            3112 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)                                                                           3112 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)_mexican                                                                   3112 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican                                                              3112 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)_cuban                                                                     3112 non-null int64
# hispanic or latino and race_total population_hispanic or latino (of any race)_other hispanic or latino                                                  3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino                                                                                     3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_white alone                                                                         3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_black or african american alone                                                     3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone                                             3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_asian alone                                                                         3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_native hawaiian and other pacific islander alone                                    3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_some other race alone                                                               3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_two or more races                                                                   3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_two or more races_two races including some other race                               3112 non-null int64
# hispanic or latino and race_total population_not hispanic or latino_two or more races_two races excluding some other race -  and three or more races    3112 non-null int64
# total housing units                                                                                                                                     3112 non-null int64
# citizen -  voting age population_citizen -  18 and over population                                                                                      3112 non-null int64
# citizen -  voting age population_citizen -  18 and over population_male                                                                                 3112 non-null int64
# citizen -  voting age population_citizen -  18 and over population_female                                                                               3112 non-null int64
# sex and age_total population                                                                                                                            3112 non-null int64
# sex and age_total population_male                                                                                                                       3112 non-null int64
# sex and age_total population_female                                                                                                                     3112 non-null int64
# sex and age_total population_sex ratio (males per 100 females)                                                                                          3112 non-null float64
# sex and age_total population_under 5 years                                                                                                              3112 non-null int64
# sex and age_total population_5 to 9 years                                                                                                               3112 non-null int64
# sex and age_total population_10 to 14 years                                                                                                             3112 non-null int64
# sex and age_total population_15 to 19 years                                                                                                             3112 non-null int64
# sex and age_total population_20 to 24 years                                                                                                             3112 non-null int64
# sex and age_total population_25 to 34 years                                                                                                             3112 non-null int64
# sex and age_total population_35 to 44 years                                                                                                             3112 non-null int64
# sex and age_total population_45 to 54 years                                                                                                             3112 non-null int64
# sex and age_total population_55 to 59 years                                                                                                             3112 non-null int64
# sex and age_total population_60 to 64 years                                                                                                             3112 non-null int64
# sex and age_total population_65 to 74 years                                                                                                             3112 non-null int64
# sex and age_total population_75 to 84 years                                                                                                             3112 non-null int64
# sex and age_total population_85 years and over                                                                                                          3112 non-null int64
# sex and age_total population_median age (years)                                                                                                         3112 non-null float64
# sex and age_total population_under 18 years                                                                                                             3112 non-null int64
# sex and age_total population_16 years and over                                                                                                          3112 non-null int64
# sex and age_total population_18 years and over                                                                                                          3112 non-null int64
# sex and age_total population_21 years and over                                                                                                          3112 non-null int64
# sex and age_total population_62 years and over                                                                                                          3112 non-null int64
# sex and age_total population_65 years and over                                                                                                          3112 non-null int64
# sex and age_total population_18 years and over_1                                                                                                        3112 non-null int64
# sex and age_total population_18 years and over_male                                                                                                     3112 non-null int64
# sex and age_total population_18 years and over_female                                                                                                   3112 non-null int64
# sex and age_total population_18 years and over_sex ratio (males per 100 females)                                                                        3112 non-null float64
# sex and age_total population_65 years and over_1                                                                                                        3112 non-null int64
# sex and age_total population_65 years and over_male                                                                                                     3112 non-null int64
# sex and age_total population_65 years and over_female                                                                                                   3112 non-null int64
# dtypes: float64(4), int64(89), object(2)
# memory usage: 2.3+ MB

# %%
clean.select_dtypes(include = "object").head() # Checking any last non-number columns
# Out:
#            County    State
# 0  Autauga County  Alabama
# 1  Baldwin County  Alabama
# 2  Barbour County  Alabama
# 3     Bibb County  Alabama
# 4   Blount County  Alabama

# %% [markdown]
# # 2. Exploratory Data Analysis

# %% [markdown]
# ## Background literature on diabetes risk factors

# %% [markdown]
# From https://www.mayoclinic.org/diseases-conditions/diabetes/symptoms-causes/syc-20371444
#
# Risk factors for prediabetes and type 2 diabetes
#
# Researchers don't fully understand why some people develop prediabetes and type 2 diabetes and others don't. It's clear that certain factors increase the risk, however, including:
#
# Weight: The more fatty tissue you have, the more resistant your cells become to insulin.
# Inactivity. The less active you are, the greater your risk. Physical activity helps you control your weight, uses up glucose as energy and makes your cells more sensitive to insulin.
#
# Family history: Your risk increases if a parent or sibling has type 2 diabetes.
#
# Race or ethnicity: Although it's unclear why, certain people — including Black, Hispanic, American Indian and Asian American people — are at higher risk.
#
# Age: Your risk increases as you get older. This may be because you tend to exercise less, lose muscle mass and gain weight as you age. But type 2 diabetes is also increasing among children, adolescents and younger adults.
#
# Gestational diabetes: If you developed gestational diabetes when you were pregnant, your risk of developing prediabetes and type 2 diabetes later increases. If you gave birth to a baby weighing more than 9 pounds (4 kilograms), you're also at risk of type 2 diabetes.
#
# Polycystic ovary syndrome: For women, having polycystic ovary syndrome — a common condition characterized by irregular menstrual periods, excess hair growth and obesity — increases the risk of diabetes.
#
# High blood pressure: Having blood pressure over 140/90 millimeters of mercury (mm Hg) is linked to an increased risk of type 2 diabetes.
#
# Abnormal cholesterol and triglyceride levels: If you have low levels of high-density lipoprotein (HDL), or "good," cholesterol, your risk of type 2 diabetes is higher. Triglycerides are another type of fat carried in the blood. People with high levels of triglycerides have an increased risk of type 2 diabetes. Your doctor can let you know what your cholesterol and triglyceride levels are.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ## Exploratory Graphs
#
# We explored the relationships between diabetes number and known factors that are related to diabetes development including obesity, physical inactivity, age, and race/ethnicity. Obesity, physical inactivity, and age had somewhat linear relationships with diabetes rates, which we expected based on prior research. Other features explored (median age, and race/ethnicity) were not strongly correlated to diabetes number.
#
# Using a correlation matrix, we identified features that were highly correlated with obesity number and removed those with correlations of 0.95 or higher, to avoid multicollinearity when estimating models.

# %%
plt.plot(clean.iloc[:,7], clean.Diabetes_Number, 'o');
plt.title("Diabetes Number vs Population Size")
plt.xlabel("Population Size")
plt.ylabel("Diabetes Number")
plt.show()
# just trying to see if population size itself is correlated w/ diabetes rates

# %%
plt.plot(clean.Obesity_Number.astype(int), clean.Diabetes_Number, 'o');
plt.title("Diabetes Number vs Obesity Number")
plt.xlabel("Obesity Number")
plt.ylabel("Diabetes Number")
plt.show()
# Seems like  linear relationship between obesity rates and diabetes rates?

# %%
plt.plot(clean.Physical_Inactivity_Number, clean.Diabetes_Number, 'o');
plt.title("Diabetes Number vs Physical Inactivity Number")
plt.xlabel("Physical Inactivity Number")
plt.ylabel("Diabetes Number")
plt.show()
# Relationship between physical inactivity rates and diabetes rates
# Somewhat linear too!

# %%
plt.plot(clean.iloc[:,81], clean.Diabetes_Number, 'o');
plt.title("Diabetes Number vs Median Age")
plt.xlabel("Median Age")
plt.ylabel("Diabetes Number")
plt.show()
# looks like median age doesn't say too much

# %%
plt.plot(clean.iloc[:,87], clean.Diabetes_Number, 'o');
plt.title("Diabetes Number vs Population >= 65 years old")
plt.xlabel("Population >= 65 years old")
plt.ylabel("Diabetes Number")
plt.show()
# population 65 yrs and older
# linear !

# %%
nonwhitepopulation = clean.iloc[:,7] - clean.iloc[:,11]
plt.plot(nonwhitepopulation, clean.Diabetes_Number, 'o');
plt.title("Diabetes Number vs Non-White Population")
plt.xlabel("Non-White Population")
plt.ylabel("Diabetes Number")
plt.show()
# the proportion of the county population that is NOT monoracial white 
# doesn't seem to be strongly correlated

# %%
hispanicpopulation = clean.iloc[:,45]
plt.plot(hispanicpopulation, clean.Diabetes_Number, 'o');
plt.title("Diabetes Number vs Hispanic Population")
plt.xlabel("Hispanic Population")
plt.ylabel("Diabetes Number")
plt.show()
# proportion of county population that is hispanic (of any race)

# %%
plt.plot(clean.iloc[:,6], clean.Diabetes_Number, 'o');
plt.title("Diabetes Number vs Sex Ratio Above 65 Years Old")
plt.xlabel("Sex Ratio (Males Per 100 Females), Above 65 Years Old")
plt.ylabel("Diabetes Number")
plt.show()
# sex ratio (males per 100 females), above 65
# also doesn't seem to be strongly correlated

# %% [markdown]
# # 3. Prepare to fit models

# %%
from sklearn import preprocessing

# normalizing all the data 
# (pulled from https://stackoverflow.com/questions/26414913/normalize-columns-of-pandas-data-frame)

clean2 = clean.drop(["County", "CountyFIPS", "Diabetes_Number"], 1) # dropping county labels and the dependent variable
clean2 = pd.get_dummies(clean2) # dummifying the state feature 

#Monica added on 10.18
min_max_scaler = preprocessing.MinMaxScaler()

# normalizing features 
X = pd.DataFrame(min_max_scaler.fit_transform(clean2), columns=clean2.columns, index=clean2.index) 




    
# making y    
y = clean.Diabetes_Number

# %%
# double check data 

X.info(verbose = True)
y
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3112 entries, 0 to 3219
# Data columns (total 142 columns):
# Obesity_Number                                                                                                                                          float64
# Physical_Inactivity_Number                                                                                                                              float64
# sex and age_total population_65 years and over_sex ratio (males per 100 females)                                                                        float64
# race_total population                                                                                                                                   float64
# race_total population_one race                                                                                                                          float64
# race_total population_two or more races                                                                                                                 float64
# race_total population_one race_1                                                                                                                        float64
# race_total population_one race_white                                                                                                                    float64
# race_total population_one race_black or african american                                                                                                float64
# race_total population_one race_american indian and alaska native                                                                                        float64
# race_total population_one race_american indian and alaska native_cherokee tribal grouping                                                               float64
# race_total population_one race_american indian and alaska native_chippewa tribal grouping                                                               float64
# race_total population_one race_american indian and alaska native_navajo tribal grouping                                                                 float64
# race_total population_one race_american indian and alaska native_sioux tribal grouping                                                                  float64
# race_total population_one race_asian                                                                                                                    float64
# race_total population_one race_asian_asian indian                                                                                                       float64
# race_total population_one race_asian_chinese                                                                                                            float64
# race_total population_one race_asian_filipino                                                                                                           float64
# race_total population_one race_asian_japanese                                                                                                           float64
# race_total population_one race_asian_korean                                                                                                             float64
# race_total population_one race_asian_vietnamese                                                                                                         float64
# race_total population_one race_asian_other asian                                                                                                        float64
# race_total population_one race_native hawaiian and other pacific islander                                                                               float64
# race_total population_one race_native hawaiian and other pacific islander_native hawaiian                                                               float64
# race_total population_one race_native hawaiian and other pacific islander_guamanian or chamorro                                                         float64
# race_total population_one race_native hawaiian and other pacific islander_samoan                                                                        float64
# race_total population_one race_native hawaiian and other pacific islander_other pacific islander                                                        float64
# race_total population_one race_some other race                                                                                                          float64
# race_total population_two or more races_1                                                                                                               float64
# race_total population_two or more races_white and black or african american                                                                             float64
# race_total population_two or more races_white and american indian and alaska native                                                                     float64
# race_total population_two or more races_white and asian                                                                                                 float64
# race_total population_two or more races_black or african american and american indian and alaska native                                                 float64
# race alone or in combination with one or more other races_total population                                                                              float64
# race alone or in combination with one or more other races_total population_white                                                                        float64
# race alone or in combination with one or more other races_total population_black or african american                                                    float64
# race alone or in combination with one or more other races_total population_american indian and alaska native                                            float64
# race alone or in combination with one or more other races_total population_asian                                                                        float64
# race alone or in combination with one or more other races_total population_native hawaiian and other pacific islander                                   float64
# race alone or in combination with one or more other races_total population_some other race                                                              float64
# hispanic or latino and race_total population                                                                                                            float64
# hispanic or latino and race_total population_hispanic or latino (of any race)                                                                           float64
# hispanic or latino and race_total population_hispanic or latino (of any race)_mexican                                                                   float64
# hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican                                                              float64
# hispanic or latino and race_total population_hispanic or latino (of any race)_cuban                                                                     float64
# hispanic or latino and race_total population_hispanic or latino (of any race)_other hispanic or latino                                                  float64
# hispanic or latino and race_total population_not hispanic or latino                                                                                     float64
# hispanic or latino and race_total population_not hispanic or latino_white alone                                                                         float64
# hispanic or latino and race_total population_not hispanic or latino_black or african american alone                                                     float64
# hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone                                             float64
# hispanic or latino and race_total population_not hispanic or latino_asian alone                                                                         float64
# hispanic or latino and race_total population_not hispanic or latino_native hawaiian and other pacific islander alone                                    float64
# hispanic or latino and race_total population_not hispanic or latino_some other race alone                                                               float64
# hispanic or latino and race_total population_not hispanic or latino_two or more races                                                                   float64
# hispanic or latino and race_total population_not hispanic or latino_two or more races_two races including some other race                               float64
# hispanic or latino and race_total population_not hispanic or latino_two or more races_two races excluding some other race -  and three or more races    float64
# total housing units                                                                                                                                     float64
# citizen -  voting age population_citizen -  18 and over population                                                                                      float64
# citizen -  voting age population_citizen -  18 and over population_male                                                                                 float64
# citizen -  voting age population_citizen -  18 and over population_female                                                                               float64
# sex and age_total population                                                                                                                            float64
# sex and age_total population_male                                                                                                                       float64
# sex and age_total population_female                                                                                                                     float64
# sex and age_total population_sex ratio (males per 100 females)                                                                                          float64
# sex and age_total population_under 5 years                                                                                                              float64
# sex and age_total population_5 to 9 years                                                                                                               float64
# sex and age_total population_10 to 14 years                                                                                                             float64
# sex and age_total population_15 to 19 years                                                                                                             float64
# sex and age_total population_20 to 24 years                                                                                                             float64
# sex and age_total population_25 to 34 years                                                                                                             float64
# sex and age_total population_35 to 44 years                                                                                                             float64
# sex and age_total population_45 to 54 years                                                                                                             float64
# sex and age_total population_55 to 59 years                                                                                                             float64
# sex and age_total population_60 to 64 years                                                                                                             float64
# sex and age_total population_65 to 74 years                                                                                                             float64
# sex and age_total population_75 to 84 years                                                                                                             float64
# sex and age_total population_85 years and over                                                                                                          float64
# sex and age_total population_median age (years)                                                                                                         float64
# sex and age_total population_under 18 years                                                                                                             float64
# sex and age_total population_16 years and over                                                                                                          float64
# sex and age_total population_18 years and over                                                                                                          float64
# sex and age_total population_21 years and over                                                                                                          float64
# sex and age_total population_62 years and over                                                                                                          float64
# sex and age_total population_65 years and over                                                                                                          float64
# sex and age_total population_18 years and over_1                                                                                                        float64
# sex and age_total population_18 years and over_male                                                                                                     float64
# sex and age_total population_18 years and over_female                                                                                                   float64
# sex and age_total population_18 years and over_sex ratio (males per 100 females)                                                                        float64
# sex and age_total population_65 years and over_1                                                                                                        float64
# sex and age_total population_65 years and over_male                                                                                                     float64
# sex and age_total population_65 years and over_female                                                                                                   float64
# State_Alabama                                                                                                                                           float64
# State_Alaska                                                                                                                                            float64
# State_Arizona                                                                                                                                           float64
# State_Arkansas                                                                                                                                          float64
# State_California                                                                                                                                        float64
# State_Colorado                                                                                                                                          float64
# State_Connecticut                                                                                                                                       float64
# State_Delaware                                                                                                                                          float64
# State_District of Columbia                                                                                                                              float64
# State_Florida                                                                                                                                           float64
# State_Georgia                                                                                                                                           float64
# State_Hawaii                                                                                                                                            float64
# State_Idaho                                                                                                                                             float64
# State_Illinois                                                                                                                                          float64
# State_Indiana                                                                                                                                           float64
# State_Iowa                                                                                                                                              float64
# State_Kansas                                                                                                                                            float64
# State_Kentucky                                                                                                                                          float64
# State_Louisiana                                                                                                                                         float64
# State_Maine                                                                                                                                             float64
# State_Maryland                                                                                                                                          float64
# State_Massachusetts                                                                                                                                     float64
# State_Michigan                                                                                                                                          float64
# State_Minnesota                                                                                                                                         float64
# State_Mississippi                                                                                                                                       float64
# State_Missouri                                                                                                                                          float64
# State_Montana                                                                                                                                           float64
# State_Nebraska                                                                                                                                          float64
# State_Nevada                                                                                                                                            float64
# State_New Hampshire                                                                                                                                     float64
# State_New Jersey                                                                                                                                        float64
# State_New Mexico                                                                                                                                        float64
# State_New York                                                                                                                                          float64
# State_North Carolina                                                                                                                                    float64
# State_North Dakota                                                                                                                                      float64
# State_Ohio                                                                                                                                              float64
# State_Oklahoma                                                                                                                                          float64
# State_Oregon                                                                                                                                            float64
# State_Pennsylvania                                                                                                                                      float64
# State_Rhode Island                                                                                                                                      float64
# State_South Carolina                                                                                                                                    float64
# State_South Dakota                                                                                                                                      float64
# State_Tennessee                                                                                                                                         float64
# State_Texas                                                                                                                                             float64
# State_Utah                                                                                                                                              float64
# State_Vermont                                                                                                                                           float64
# State_Virginia                                                                                                                                          float64
# State_Washington                                                                                                                                        float64
# State_West Virginia                                                                                                                                     float64
# State_Wisconsin                                                                                                                                         float64
# State_Wyoming                                                                                                                                           float64
# dtypes: float64(142)
# memory usage: 3.4 MB
# 0        5178
# 1       16707
# 2        3400
# 3        2371
# 4        6282
#         ...
# 3215     2560
# 3216      439
# 3217     1440
# 3218      637
# 3219      601
# Name: Diabetes_Number, Length: 3112, dtype: int64

# %% [markdown]
# ## 3.2 Partition Data
#
# We partitioned our data into training, validation, and test sets. Of the original data, 60% went into the training set, 20% went into the validation set, and 20% went into the test set. The training set was used to first identify the model that best fits the data. The validation set was used as we were testing different models that each model wasn’t overfitting to the training set. After identifying the model that was best for both the training and validation sets, we then used the model to predict on our test set.

# %%
import numpy as np
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, LinearRegression
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

# %%
# set the random seed
np.random.seed(10)

# split the data into training and test data
# train_test_split returns 4 values: X_train, X_test, y_train, y_test

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.80, test_size=0.20)

# %%
# then split the training data for cross validation (actual training data and then cross-validation set)
# Returns 4 values: X_train, X_validate, y_train, y_validate

np.random.seed(10)

X_train, X_validate, y_train, y_validate = train_test_split(X_train, y_train, train_size=0.75, test_size=0.25)

# %% [markdown]
# # 3.3 Feature Selection

# %%
import matplotlib.pyplot as plt
import statsmodels.graphics.api as smg

# %%
#from https://www.statsmodels.org/stable/generated/statsmodels.graphics.correlation.plot_corr.html#statsmodels.graphics.correlation.plot_corr
# checking pairwise correlation for all the Xs 
# seems to be that a lot of the county population features are highly correlated 
# and all the less correlated features are probably the dummies for each of the states

corr_matrix = np.corrcoef(X_train.T)
smg.plot_corr(corr_matrix)
plt.show()

# %%
# checking correlation with Obesity Number
# not sure what is too high to drop... I think if we are only concerned w/ prediction correlation doesn't matter, 
# but anything more than 0.95 correlation seems way too high 

# can play around with this to see what variables drop out!

corrs = corr_matrix[0,:] < 0.95

corrs[0] = True

print(X_train.columns[~corrs]) # these are the variables to be dropped (bc they have almost perfect correlation)

# makes sense that Physical_Inactivity will be dropped
# makes sense that a lot that are being dropped are measures of size of whole population
    # e.g., all total population counts, total monoracial population, total citizens
# Out:
# Index(['Physical_Inactivity_Number', 'race_total population',
#        'race_total population_one race', 'race_total population_one race_1',
#        'race_total population_one race_white',
#        'race alone or in combination with one or more other races_total population',
#        'race alone or in combination with one or more other races_total population_white',
#        'hispanic or latino and race_total population',
#        'hispanic or latino and race_total population_not hispanic or latino',
#        'total housing units',
#        'citizen -  voting age population_citizen -  18 and over population',
#        'citizen -  voting age population_citizen -  18 and over population_male',
#        'citizen -  voting age population_citizen -  18 and over population_female',
#        'sex and age_total population', 'sex and age_total population_male',
#        'sex and age_total population_female',
#        'sex and age_total population_under 5 years',
#        'sex and age_total population_5 to 9 years',
#        'sex and age_total population_10 to 14 years',
#        'sex and age_total population_15 to 19 years',
#        'sex and age_total population_20 to 24 years',
#        'sex and age_total population_25 to 34 years',
#        'sex and age_total population_35 to 44 years',
#        'sex and age_total population_45 to 54 years',
#        'sex and age_total population_55 to 59 years',
#        'sex and age_total population_60 to 64 years',
#        'sex and age_total population_65 to 74 years',
#        'sex and age_total population_75 to 84 years',
#        'sex and age_total population_85 years and over',
#        'sex and age_total population_under 18 years',
#        'sex and age_total population_16 years and over',
#        'sex and age_total population_18 years and over',
#        'sex and age_total population_21 years and over',
#        'sex and age_total population_62 years and over',
#        'sex and age_total population_65 years and over',
#        'sex and age_total population_18 years and over_1',
#        'sex and age_total population_18 years and over_male',
#        'sex and age_total population_18 years and over_female',
#        'sex and age_total population_65 years and over_1',
#        'sex and age_total population_65 years and over_male',
#        'sex and age_total population_65 years and over_female'],
#       dtype='object')

# %%
# taking out all features that have a correlation higher than 0.95, 101 features remain

X_train = X_train[X_train.columns[corrs]]
X_validate = X_validate[X_validate.columns[corrs]]
X_test = X_test[X_test.columns[corrs]]
X_train.info(verbose = True) 

# makes sense that a lot of the subgroup features are left (e.g., total Black population) 
# and also all(?) the state dummy variables
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1866 entries, 2050 to 2124
# Data columns (total 101 columns):
# Obesity_Number                                                                                                                                          float64
# sex and age_total population_65 years and over_sex ratio (males per 100 females)                                                                        float64
# race_total population_two or more races                                                                                                                 float64
# race_total population_one race_black or african american                                                                                                float64
# race_total population_one race_american indian and alaska native                                                                                        float64
# race_total population_one race_american indian and alaska native_cherokee tribal grouping                                                               float64
# race_total population_one race_american indian and alaska native_chippewa tribal grouping                                                               float64
# race_total population_one race_american indian and alaska native_navajo tribal grouping                                                                 float64
# race_total population_one race_american indian and alaska native_sioux tribal grouping                                                                  float64
# race_total population_one race_asian                                                                                                                    float64
# race_total population_one race_asian_asian indian                                                                                                       float64
# race_total population_one race_asian_chinese                                                                                                            float64
# race_total population_one race_asian_filipino                                                                                                           float64
# race_total population_one race_asian_japanese                                                                                                           float64
# race_total population_one race_asian_korean                                                                                                             float64
# race_total population_one race_asian_vietnamese                                                                                                         float64
# race_total population_one race_asian_other asian                                                                                                        float64
# race_total population_one race_native hawaiian and other pacific islander                                                                               float64
# race_total population_one race_native hawaiian and other pacific islander_native hawaiian                                                               float64
# race_total population_one race_native hawaiian and other pacific islander_guamanian or chamorro                                                         float64
# race_total population_one race_native hawaiian and other pacific islander_samoan                                                                        float64
# race_total population_one race_native hawaiian and other pacific islander_other pacific islander                                                        float64
# race_total population_one race_some other race                                                                                                          float64
# race_total population_two or more races_1                                                                                                               float64
# race_total population_two or more races_white and black or african american                                                                             float64
# race_total population_two or more races_white and american indian and alaska native                                                                     float64
# race_total population_two or more races_white and asian                                                                                                 float64
# race_total population_two or more races_black or african american and american indian and alaska native                                                 float64
# race alone or in combination with one or more other races_total population_black or african american                                                    float64
# race alone or in combination with one or more other races_total population_american indian and alaska native                                            float64
# race alone or in combination with one or more other races_total population_asian                                                                        float64
# race alone or in combination with one or more other races_total population_native hawaiian and other pacific islander                                   float64
# race alone or in combination with one or more other races_total population_some other race                                                              float64
# hispanic or latino and race_total population_hispanic or latino (of any race)                                                                           float64
# hispanic or latino and race_total population_hispanic or latino (of any race)_mexican                                                                   float64
# hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican                                                              float64
# hispanic or latino and race_total population_hispanic or latino (of any race)_cuban                                                                     float64
# hispanic or latino and race_total population_hispanic or latino (of any race)_other hispanic or latino                                                  float64
# hispanic or latino and race_total population_not hispanic or latino_white alone                                                                         float64
# hispanic or latino and race_total population_not hispanic or latino_black or african american alone                                                     float64
# hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone                                             float64
# hispanic or latino and race_total population_not hispanic or latino_asian alone                                                                         float64
# hispanic or latino and race_total population_not hispanic or latino_native hawaiian and other pacific islander alone                                    float64
# hispanic or latino and race_total population_not hispanic or latino_some other race alone                                                               float64
# hispanic or latino and race_total population_not hispanic or latino_two or more races                                                                   float64
# hispanic or latino and race_total population_not hispanic or latino_two or more races_two races including some other race                               float64
# hispanic or latino and race_total population_not hispanic or latino_two or more races_two races excluding some other race -  and three or more races    float64
# sex and age_total population_sex ratio (males per 100 females)                                                                                          float64
# sex and age_total population_median age (years)                                                                                                         float64
# sex and age_total population_18 years and over_sex ratio (males per 100 females)                                                                        float64
# State_Alabama                                                                                                                                           float64
# State_Alaska                                                                                                                                            float64
# State_Arizona                                                                                                                                           float64
# State_Arkansas                                                                                                                                          float64
# State_California                                                                                                                                        float64
# State_Colorado                                                                                                                                          float64
# State_Connecticut                                                                                                                                       float64
# State_Delaware                                                                                                                                          float64
# State_District of Columbia                                                                                                                              float64
# State_Florida                                                                                                                                           float64
# State_Georgia                                                                                                                                           float64
# State_Hawaii                                                                                                                                            float64
# State_Idaho                                                                                                                                             float64
# State_Illinois                                                                                                                                          float64
# State_Indiana                                                                                                                                           float64
# State_Iowa                                                                                                                                              float64
# State_Kansas                                                                                                                                            float64
# State_Kentucky                                                                                                                                          float64
# State_Louisiana                                                                                                                                         float64
# State_Maine                                                                                                                                             float64
# State_Maryland                                                                                                                                          float64
# State_Massachusetts                                                                                                                                     float64
# State_Michigan                                                                                                                                          float64
# State_Minnesota                                                                                                                                         float64
# State_Mississippi                                                                                                                                       float64
# State_Missouri                                                                                                                                          float64
# State_Montana                                                                                                                                           float64
# State_Nebraska                                                                                                                                          float64
# State_Nevada                                                                                                                                            float64
# State_New Hampshire                                                                                                                                     float64
# State_New Jersey                                                                                                                                        float64
# State_New Mexico                                                                                                                                        float64
# State_New York                                                                                                                                          float64
# State_North Carolina                                                                                                                                    float64
# State_North Dakota                                                                                                                                      float64
# State_Ohio                                                                                                                                              float64
# State_Oklahoma                                                                                                                                          float64
# State_Oregon                                                                                                                                            float64
# State_Pennsylvania                                                                                                                                      float64
# State_Rhode Island                                                                                                                                      float64
# State_South Carolina                                                                                                                                    float64
# State_South Dakota                                                                                                                                      float64
# State_Tennessee                                                                                                                                         float64
# State_Texas                                                                                                                                             float64
# State_Utah                                                                                                                                              float64
# State_Vermont                                                                                                                                           float64
# State_Virginia                                                                                                                                          float64
# State_Washington                                                                                                                                        float64
# State_West Virginia                                                                                                                                     float64
# State_Wisconsin                                                                                                                                         float64
# State_Wyoming                                                                                                                                           float64
# dtypes: float64(101)
# memory usage: 1.5 MB

# %% [markdown]
# ## Normal OLS

# %%
# just gonna run a normal OLS

lin_reg = LinearRegression(normalize=True)

# fit the model
lin_model = lin_reg.fit(X_train, y_train)

# %%
print(lin_model.coef_)
print(lin_model.intercept_)
print(lin_model.coef_.shape)
# Out:
# [ 4.44596580e+05 -2.85737925e+03  1.67917933e+16 -5.58728595e+06
#  -6.74208966e+04  1.00686106e+03 -5.04811356e+02 -1.07904614e+04
#  -5.28766731e+02 -5.51553971e+15  6.57883135e+14  1.75212625e+15
#   1.28370415e+15  5.17642795e+14  7.98678794e+14  7.86476803e+14
#   5.89725339e+14  7.86282798e+15 -4.22522282e+15 -4.30523456e+14
#  -1.09405183e+15 -2.32578078e+15 -9.61413329e+06 -1.67917933e+16
#   2.90266521e+04  2.15376696e+05  4.06725273e+05 -2.89885171e+04
#   5.84578150e+06  1.09004544e+05  1.66790133e+05  7.87461471e+05
#   1.02155299e+07 -8.29322419e+14  6.29757259e+14  4.68398426e+13
#   1.67047966e+14  1.85061856e+14  6.90475690e+04 -6.27984232e+03
#   2.28278444e+04 -6.93496353e+06  1.92942452e+05  2.43278726e+04
#   9.00330312e+13 -5.47061148e+12 -8.45624197e+13 -6.08467079e+02
#   2.44197472e+03 -1.14574052e+03 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14 -1.63959250e+14 -1.63959250e+14 -1.63959250e+14
#  -1.63959250e+14]
# 163959249945217.88
# (101,)

# %%
# Create a dataframe with the coefficient and feature names
# this is unintelligible with 101 variables lmao

lin_reg_data = pd.DataFrame([lin_model.coef_, X_train.columns]).T
lin_reg_data.columns = ['Coefficient', 'Feature']
# Plot
ax = sns.barplot(x="Coefficient", y="Feature", data=lin_reg_data)
ax.set_title("OLS Coefficients")

# some of these coefficients seem high since y is normalized, but maybe not an issue bc prediction...
# Out:
# Text(0.5, 1.0, 'OLS Coefficients')

# %%
# predict the number of diabetes, using OLS parameters
lin_pred = lin_model.predict(X_validate)

# plot the residuals on a scatter plot
plt.scatter(lin_pred, y_validate)
plt.title('Linear Model (OLS) Predicted v. Actual')
plt.xlabel('actual value')
plt.ylabel('predicted value')
plt.show()


# this looks decent !! but can maybe do better w/ lasso?

# %%
def rmse(pred, actual):
    return pow(np.mean(pow((pred-actual), 2)), 0.5)

# %%
rmse(lin_pred, y_validate)
# Out:
# 2144.9723039785904

# %% [markdown]
# # 4. Train Models
# ## 4.1 Model Description
#
# - Ordinary Least Squares regression identifies a best fit model that minimizes the residual sums of squares
# - Ridge regression is similar to Ordinary Least Squares regression except it regularizes the model using a penalty term, lambda, that constrains feature coefficients.
# - Lasso is like Ridge regression in that it also regularizes the model using a lambda as a penalty term to constrain coefficients. However, in Ridge equations, the terms are squared to account for negative values leading to larger penalties, whereas Lasso equations take the absolute value to account for negative values leading to smaller penalties. In addition, Lasso is more likely to shrink coefficients down to zero than Ridge.
# - Least Angle Regression (LARS) Lasso is another regularizing model that is similar to forward stepwise regression, at each step identifying “most correlated with the target. When there are multiple features having equal correlation, instead of continuing along the same feature, it proceeds in a direction equiangular between the features” (https://scikit-learn.org/stable/modules/linear_model.html#least-angle-regression). LARS Lasso is more sensitive to noise and therefore may overfit the training data as compared to the other models.
# - Elastic Net is a hybrid of ridge regression and lasso regularization. A limitation of lasso is that prediction is sometimes too dependent on a particular variable causing bias. Using a grouping effect, elastic net outperforms lasso on data with highly correlated predictors.
# - Orthogonal Matching Pursuit, which was developed as an extension of Matching Pursuit, uses an iterative process to calculate an approximation error that is used in the following iteration to determine the selection procedure.
#
# ## 4.2 Train Models & Hyperparameter Tuning

# %% [markdown]
# ### Ridge

# %%
# Ridge alpha search

ridge_reg = Ridge()

param_grid = {'alpha': np.arange(0.01, 0.2, 0.01),
               'normalize': ['True', 'False'],
             'fit_intercept': ['True', 'False'],
             'solver': ['auto', 'svd', 'cholesky', 'lsqr']}

ridge_grid_reg = GridSearchCV(ridge_reg, param_grid, cv=3, iid=False)
ridge_grid_reg.fit(X_train, y_train)

best_index = np.argmax(ridge_grid_reg.cv_results_["mean_test_score"])
best_ridge_pred = ridge_grid_reg.best_estimator_.predict(X_validate)

plt.scatter(ridge_grid_reg.cv_results_['param_alpha'], ridge_grid_reg.cv_results_["mean_test_score"])
plt.xlabel('lambda')
plt.ylabel('mean test score (higher = better)')
plt.show()

print(ridge_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(ridge_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', ridge_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_ridge_pred, y_validate))
# Out:
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# {'alpha': 0.02, 'fit_intercept': 'True', 'normalize': 'True', 'solver': 'lsqr'}
# Best CV R^2: 0.9418671400775698
# Validation R^2: 0.9744141288473217
# Validation RMSE 2298.87269311901

# %% [markdown]
# ### Lasso

# %%
# Lasso alpha search

#I am not sure about the random method for variable selection, 
# makes it difficult to choose the best Lasso model bc you can't zoom in on a range of lambdas..

# set the random seed
#np.random.seed(20)

lasso_reg = Lasso()

param_grid = {'alpha': np.arange(1.0, 1.2, .01),
               'normalize': ['True', 'False'],
             'fit_intercept': ['True', 'False'],
             'selection': ['cyclic']}

lasso_grid_reg = GridSearchCV(lasso_reg, param_grid, cv=3, iid=False)
lasso_grid_reg.fit(X_train, y_train)

best_index = np.argmax(lasso_grid_reg.cv_results_["mean_test_score"])
best_lasso_pred = lasso_grid_reg.best_estimator_.predict(X_validate)


plt.scatter(lasso_grid_reg.cv_results_['param_alpha'], lasso_grid_reg.cv_results_["mean_test_score"])
plt.xlabel('lambda')
plt.ylabel('mean test score (higher = better)')
plt.show()

print(lasso_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(lasso_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', lasso_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_lasso_pred, y_validate))
# Out:
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# {'alpha': 1.06, 'fit_intercept': 'True', 'normalize': 'True', 'selection': 'cyclic'}
# Best CV R^2: 0.9469352132782314
# Validation R^2: 0.9831571207355266
# Validation RMSE 1865.1895993694102

# %% [markdown]
# ### LARS Lasso

# %%
# LARS Lasso alpha search 
# https://scikit-learn.org/stable/modules/linear_model.html#least-angle-regression
# this did not seem to want to converge...

from sklearn import linear_model

lars_reg = linear_model.LassoLars()

param_grid = {'alpha': np.arange(0.1, 0.3, .01),
               'normalize': ['True', 'False'],
             'fit_intercept': ['True', 'False']}

lars_grid_reg = GridSearchCV(lars_reg, param_grid, cv=3, iid=False)
lars_grid_reg.fit(X_train, y_train)

best_index = np.argmax(lars_grid_reg.cv_results_["mean_test_score"])
best_lars_pred = lars_grid_reg.best_estimator_.predict(X_validate)


plt.scatter(lars_grid_reg.cv_results_['param_alpha'], lars_grid_reg.cv_results_["mean_test_score"])
plt.xlabel('lambda')
plt.ylabel('mean test score (higher = better)')
plt.show()

print(lars_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(lars_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', lars_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_lars_pred, y_validate))
# Out:
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 95 iterations, i.e. alpha=1.014e-01, with an active set of 77 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 95 iterations, i.e. alpha=1.014e-01, with an active set of 77 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 95 iterations, i.e. alpha=1.014e-01, with an active set of 77 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 95 iterations, i.e. alpha=1.014e-01, with an active set of 77 regressors, and the smallest cholesky pivot element being 1.054e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# ...
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 3 iterations, i.e. alpha=1.482e+02, with an active set of 3 regressors, and the smallest cholesky pivot element being 1.490e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.560e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 2.220e-16. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.447e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.942e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:582: ConvergenceWarning: Regressors in active set degenerate. Dropping a regressor, after 175 iterations, i.e. alpha=1.380e+01, with an active set of 91 regressors, and the smallest cholesky pivot element being 3.495e-08. Reduce max_iter or increase eps parameters.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_least_angle.py:608: ConvergenceWarning: Early stopping the lars path, as the residues are small and the current value of alpha is no longer well controlled. 176 iterations, alpha=1.503e+01, previous alpha=1.114e+01, with an active set of 91 regressors.
#   ConvergenceWarning)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# {'alpha': 0.2899999999999999, 'fit_intercept': 'True', 'normalize': 'True'}
# Best CV R^2: -18851.59729579987
# Validation R^2: 0.983265645129508
# Validation RMSE 1859.1708633394157

# %% [markdown]
# ### Elastic Net

# %%
# Elastic net alpha search 
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.ElasticNet.html#sklearn.linear_model.ElasticNet
# this doesn't do too well... the benefit of this is that it allows you to use a combination of
# l1 penalty (lasso) and l2 penalty (ridge). It basically wants to go all the way to l1_ratio = 1.0, which
# is the same as a normal lasso regression. 
 
from sklearn import linear_model

eln_reg = linear_model.ElasticNet()

param_grid = {'alpha': np.arange(0.0, 0.2, .01), 
              'l1_ratio': np.arange(0, 1.1, 0.1),
               'normalize': ['True', 'False'],
             'fit_intercept': ['True', 'False']}

eln_grid_reg = GridSearchCV(eln_reg, param_grid, cv=3, iid=False)
eln_grid_reg.fit(X_train, y_train)

best_index = np.argmax(eln_grid_reg.cv_results_["mean_test_score"])
best_eln_pred = eln_grid_reg.best_estimator_.predict(X_validate)


plt.scatter(eln_grid_reg.cv_results_['param_alpha'], eln_grid_reg.cv_results_["mean_test_score"])
plt.xlabel('lambda')
plt.ylabel('mean test score (higher = better)')
plt.show()

print(eln_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(eln_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', eln_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_eln_pred, y_validate))
# Out:
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2373966506.460629, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1964671163.053393, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1367527427.0042915, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_validation.py:515: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# ...
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 777736388.2875447, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 680175641.0858798, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 777736388.2875447, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 377141050327.1577, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 436853716806.19836, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 281078477818.6424, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 377141050327.1577, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 436853716806.19836, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 281078477818.6424, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 680175641.0858798, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 777736388.2875447, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 680175641.0858798, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 777736388.2875447, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 379531342424.0717, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439344046082.63965, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 282424651319.6785, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 379531342424.0717, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439344046082.63965, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 282424651319.6785, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 621024917.0158262, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 739451352.9132798, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 621024917.0158262, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 739451352.9132798, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 379531342424.0717, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439344046082.63965, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 282424651319.6785, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 379531342424.0717, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 439344046082.63965, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 282424651319.6785, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 621024917.0158262, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 739451352.9132798, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 621024917.0158262, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 739451352.9132798, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381697920332.56665, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 441598987956.96936, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 283641904159.81647, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381697920332.56665, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 441598987956.96936, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 283641904159.81647, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 601569887.2776117, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 647138904.5714049, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 601569887.2776117, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 647138904.5714049, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381697920332.56665, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 441598987956.96936, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 283641904159.81647, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 381697920332.56665, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 441598987956.96936, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 283641904159.81647, tolerance: 61570590.51196367
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 601569887.2776117, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 647138904.5714049, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 601569887.2776117, tolerance: 85166657.61815266
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 647138904.5714049, tolerance: 97413446.32496294
#   positive)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:476: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 134533720.69492912, tolerance: 122076793.1111366
#   positive)
# {'alpha': 0.19, 'fit_intercept': 'True', 'l1_ratio': 1.0, 'normalize': 'True'}
# Best CV R^2: 0.9214278495412697
# Validation R^2: 0.9826453830085881
# Validation RMSE 1893.3126388923397

# %% [markdown]
# ### Orthogonal Matching Pursuit

# %%
# Orthogonal Matching Pursuit 
# https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.OrthogonalMatchingPursuit.html#sklearn.linear_model.OrthogonalMatchingPursuit


omp_reg = linear_model.OrthogonalMatchingPursuit()

param_grid = {'n_nonzero_coefs': np.arange(round(len(X_train.columns)/10), len(X_train.columns) + 1), 
               'normalize': ['True', 'False'],
             'fit_intercept': ['True', 'False']}

omp_grid_reg = GridSearchCV(omp_reg, param_grid, cv=3, iid=False)
omp_grid_reg.fit(X_train, y_train)

best_index = np.argmax(omp_grid_reg.cv_results_["mean_test_score"])
best_omp_pred = omp_grid_reg.best_estimator_.predict(X_validate)


plt.scatter(omp_grid_reg.cv_results_['param_n_nonzero_coefs'], omp_grid_reg.cv_results_["mean_test_score"])
plt.xlabel('lambda')
plt.ylabel('mean test score (higher = better)')
plt.show()

print(omp_grid_reg.cv_results_["params"][best_index])
print('Best CV R^2:', max(omp_grid_reg.cv_results_["mean_test_score"]))
print('Validation R^2:', omp_grid_reg.score(X_validate, y_validate))
print('Validation RMSE', rmse(best_omp_pred, y_validate))
# Out:
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/_omp.py:673: RuntimeWarning:  Orthogonal matching pursuit ended prematurely due to linear
# dependence in the dictionary. The requested precision might not have been met.
#
#   return_n_iter=True)
# /Users/jasminesanders/opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py:823: FutureWarning: The parameter 'iid' is deprecated in 0.22 and will be removed in 0.24.
#   "removed in 0.24.", FutureWarning
# {'fit_intercept': 'True', 'n_nonzero_coefs': 19, 'normalize': 'True'}
# Best CV R^2: 0.9391852858169244
# Validation R^2: 0.9777280999354824
# Validation RMSE 2144.832846678714

# %% [markdown]
# # 5. Validate and Refine Models
# ## 5.1 Predict on Validation Set
#
# With the smallest RSME, Lasso is our best model.
#
# ## 5.2 Feature Selection
#
# Our best model is Lasso, which automatically performs feature selection by taking variables that aren’t adding to the model and sets them to zero.

# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn import linear_model

#best model: {'alpha': 1.06, 'fit_intercept': 'True', 'normalize': 'True', 'selection': 'cyclic'}
#lowest RMSE of all other techniques

reg = linear_model.Lasso(alpha = 1.06, fit_intercept = True, normalize = True, selection = 'cyclic')
reg.fit(X_train, y_train)
actives = abs(reg.coef_) > 0 


lin_reg_data = pd.DataFrame([reg.coef_[actives], X_train.columns[actives]]).T
lin_reg_data.columns = ['Coefficient', 'Feature']
# Plot
ax = sns.barplot(x="Coefficient", y="Feature", data=lin_reg_data)
ax.set_title("Lasso Coefficients")

print("Remaining active features: ",X_train.columns[actives])
print("Obesity_Number coefficient: ",reg.coef_[0])
print("RMSE: ", rmse(reg.predict(X_validate), y_validate))
# Out:
# Remaining active features:  Index(['Obesity_Number',
#        'sex and age_total population_65 years and over_sex ratio (males per 100 females)',
#        'race_total population_one race_black or african american',
#        'race_total population_one race_american indian and alaska native_cherokee tribal grouping',
#        'race_total population_one race_asian_asian indian',
#        'race_total population_one race_asian_filipino',
#        'race_total population_one race_asian_japanese',
#        'race_total population_one race_asian_korean',
#        'race_total population_one race_asian_vietnamese',
#        'race_total population_one race_native hawaiian and other pacific islander_native hawaiian',
#        'race_total population_one race_native hawaiian and other pacific islander_other pacific islander',
#        'race_total population_one race_some other race',
#        'race_total population_two or more races_white and asian',
#        'hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican',
#        'hispanic or latino and race_total population_hispanic or latino (of any race)_cuban',
#        'hispanic or latino and race_total population_not hispanic or latino_white alone',
#        'hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone',
#        'hispanic or latino and race_total population_not hispanic or latino_some other race alone',
#        'sex and age_total population_sex ratio (males per 100 females)',
#        'sex and age_total population_median age (years)',
#        'sex and age_total population_18 years and over_sex ratio (males per 100 females)',
#        'State_Alabama', 'State_Arizona', 'State_Colorado', 'State_Connecticut',
#        'State_District of Columbia', 'State_Florida', 'State_Illinois',
#        'State_Indiana', 'State_Iowa', 'State_Kansas', 'State_Massachusetts',
#        'State_Minnesota', 'State_Montana', 'State_Nebraska', 'State_Nevada',
#        'State_New Jersey', 'State_New York', 'State_North Dakota',
#        'State_Ohio', 'State_Pennsylvania', 'State_Rhode Island',
#        'State_South Carolina', 'State_Tennessee', 'State_Utah',
#        'State_Vermont', 'State_Virginia', 'State_West Virginia',
#        'State_Wisconsin'],
#       dtype='object')
# Obesity_Number coefficient:  403022.62399523286
# RMSE:  1865.1895993694102

# %%
# checking which coefficients are very small relative to Obesity_Number

X_train.columns[np.logical_and(abs(reg.coef_) > 0, abs(reg.coef_) < 100)]
# Out:
# Index(['hispanic or latino and race_total population_not hispanic or latino_american indian and alaska native alone',
#        'State_Indiana', 'State_Pennsylvania', 'State_Vermont',
#        'State_West Virginia'],
#       dtype='object')

# %%
# use the model to make predictions
lasso_pred = reg.predict(X_validate)

# plot the predictions
plt.scatter(y_validate, lasso_pred)
plt.title('LASSO Model')
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.show()

# %%
# calculate the validation rmse for the LASSO model
rmse(lasso_pred, y_validate)

#LASSO looks like our winner, winner, chicken dinner!
# Out:
# 1865.1895993694102

# %% [markdown]
# ## 5.3 Test Set
#
# Lasso performed relatively well on the test set achieving a score of 2078.93. The advantage of using both a validation and test set in social sciences and public policy is the ability to modify the model at several time points to ensure that the model is not overfitting the training data (using the validation set), making adjustments after the model is run on the validation set, and then predicting how the model will do on future data using the test set.

# %%
# Dropping features from whose coefficients were very small

X2_train = X_train.drop(X_train.columns[np.logical_and(abs(reg.coef_) > 0, abs(reg.coef_) < 100)], 1)
X2_validate = X_validate.drop(X_train.columns[np.logical_and(abs(reg.coef_) > 0, abs(reg.coef_) < 100)], 1)
X2_test = X_test.drop(X_train.columns[np.logical_and(abs(reg.coef_) > 0, abs(reg.coef_) < 100)], 1)

# %%
# Retrain model

reg = linear_model.Lasso(alpha = 1.06, fit_intercept = True, normalize = True, selection = 'cyclic')
reg.fit(X2_train, y_train)
actives = abs(reg.coef_) > 0 


lin_reg_data = pd.DataFrame([reg.coef_[actives], X2_train.columns[actives]]).T
lin_reg_data.columns = ['Coefficient', 'Feature']
# Plot
ax = sns.barplot(x="Coefficient", y="Feature", data=lin_reg_data)
ax.set_title("Lasso Coefficients")

print("Remaining active features: ",X2_train.columns[actives])
print("Obesity_Number coefficient: ",reg.coef_[0])
print("RMSE: ", rmse(reg.predict(X2_validate), y_validate))
# Out:
# Remaining active features:  Index(['Obesity_Number',
#        'sex and age_total population_65 years and over_sex ratio (males per 100 females)',
#        'race_total population_one race_black or african american',
#        'race_total population_one race_american indian and alaska native_cherokee tribal grouping',
#        'race_total population_one race_asian_asian indian',
#        'race_total population_one race_asian_filipino',
#        'race_total population_one race_asian_japanese',
#        'race_total population_one race_asian_korean',
#        'race_total population_one race_asian_vietnamese',
#        'race_total population_one race_native hawaiian and other pacific islander_native hawaiian',
#        'race_total population_one race_native hawaiian and other pacific islander_other pacific islander',
#        'race_total population_one race_some other race',
#        'race_total population_two or more races_white and asian',
#        'hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican',
#        'hispanic or latino and race_total population_hispanic or latino (of any race)_cuban',
#        'hispanic or latino and race_total population_not hispanic or latino_white alone',
#        'hispanic or latino and race_total population_not hispanic or latino_some other race alone',
#        'sex and age_total population_sex ratio (males per 100 females)',
#        'sex and age_total population_median age (years)',
#        'sex and age_total population_18 years and over_sex ratio (males per 100 females)',
#        'State_Alabama', 'State_Arizona', 'State_Colorado', 'State_Connecticut',
#        'State_District of Columbia', 'State_Florida', 'State_Illinois',
#        'State_Iowa', 'State_Kansas', 'State_Massachusetts', 'State_Minnesota',
#        'State_Montana', 'State_Nebraska', 'State_Nevada', 'State_New Jersey',
#        'State_New York', 'State_North Dakota', 'State_Ohio',
#        'State_Rhode Island', 'State_South Carolina', 'State_Tennessee',
#        'State_Utah', 'State_Virginia', 'State_Wisconsin'],
#       dtype='object')
# Obesity_Number coefficient:  403060.1370996749
# RMSE:  1865.6693160922478

# %%
# Testing 
lasso_pred = reg.predict(X2_test)

# plot the predictions
plt.scatter(y_test, lasso_pred)
plt.title('LASSO Model')
plt.xlabel('actual values')
plt.ylabel('predicted values')
plt.show()

# calculate the validation rmse for the LASSO model
rmse(lasso_pred, y_test)
# Out:
# 2078.934190037076

# %% [markdown]
# # 5.4 Implement a Cross-Validation Approach
#
# In performing cross-validation using k-folds (5), we obtained an accuracy score of 0.977. K-folds cross-validation performed similarly well to the train/validation/test split which had an accuracy score of 0.983.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn import svm
from sklearn.model_selection import cross_val_score

clf = Lasso(alpha = 1.06, fit_intercept = True, normalize = True, selection = 'cyclic')

scores = cross_val_score(clf, X, y, cv=5)
scores
print(scores)
print(np.mean(scores))
# Out:
# [0.96365408 0.98662524 0.99002494 0.96239659 0.98254097]
# 0.977048365943013

# %% [markdown]
# # 6.3 Prioritizing for pilot program

# %%
# predicting on whole X (with the features dropped)

predicted_diabetes = reg.predict(X.drop(X.columns.difference(X2_train.columns), 1))


policy_pred = pd.DataFrame(list(zip(clean["County"], clean["State"], predicted_diabetes)))
policy_pred.columns = ["County", "State", "predicted_diabetes"]

# %%
# top 10 regions

policy_pred.sort_values("predicted_diabetes", ascending = False).head(n = 10)
# Out:
#                   County       State  predicted_diabetes
# 203   Los Angeles County  California       669260.664823
# 603          Cook County    Illinois       377160.415507
# 2599       Harris County       Texas       312322.350946
# 103      Maricopa County     Arizona       277545.100441
# 221     San Diego County  California       195209.066754
# 214        Orange County  California       194105.956946
# 1849       Queens County    New York       191733.934479
# 2555       Dallas County       Texas       176154.412731
# 1832        Kings County    New York       175829.182459
# 217     Riverside County  California       167282.518538

# %% [markdown]
# With the Lasso model that we ended up with, we plugged in the original data (without the county names/identifiers removed), generated the predicted "Diabetes_Number" column. This table displays the top 10 counties with the highest predicted "Diabetes_Number." It looks like counties with the highest predicted "Diabetes_Number" are located all over the country, though they also seem to be the most populated counties in the whole country in general.

# %%
actives2 = actives
actives2[49:95] = False

lin_reg_data = pd.DataFrame([reg.coef_[actives2], X2_train.columns[actives2]]).T
lin_reg_data.columns = ['Coefficient', 'Feature']
# Plot
ax = sns.barplot(x="Coefficient", y="Feature", data=lin_reg_data)
ax.set_title("Lasso Coefficients")

print("Remaining active features: ",X2_train.columns[actives2])
# Out:
# Remaining active features:  Index(['Obesity_Number',
#        'sex and age_total population_65 years and over_sex ratio (males per 100 females)',
#        'race_total population_one race_black or african american',
#        'race_total population_one race_american indian and alaska native_cherokee tribal grouping',
#        'race_total population_one race_asian_asian indian',
#        'race_total population_one race_asian_filipino',
#        'race_total population_one race_asian_japanese',
#        'race_total population_one race_asian_korean',
#        'race_total population_one race_asian_vietnamese',
#        'race_total population_one race_native hawaiian and other pacific islander_native hawaiian',
#        'race_total population_one race_native hawaiian and other pacific islander_other pacific islander',
#        'race_total population_one race_some other race',
#        'race_total population_two or more races_white and asian',
#        'hispanic or latino and race_total population_hispanic or latino (of any race)_puerto rican',
#        'hispanic or latino and race_total population_hispanic or latino (of any race)_cuban',
#        'hispanic or latino and race_total population_not hispanic or latino_white alone',
#        'hispanic or latino and race_total population_not hispanic or latino_some other race alone',
#        'sex and age_total population_sex ratio (males per 100 females)',
#        'sex and age_total population_median age (years)',
#        'sex and age_total population_18 years and over_sex ratio (males per 100 females)'],
#       dtype='object')

# %% [markdown]
# The graph above shows all active variables in our final trained model, apart from the state dummy variables. Obesity_Number is clearly very useful for predicting Diabetes_Number. Obesity_Number is not a feature that necessarily takes race, gender, and age into account. Different racial groups, gender groups, and age groups might have different rates in the Obesity_Number category, but that is not something this final analysis can tell us. However, the Lasso model did leave in many variables relating to race, gender, and age, meaning that to some extent, these groupings are accounted for.
#
# We would not be that confident deploying this sort of model in the real-world application, because it asked us to predict on Diabetes_Number, an absolute measure. It seems that its predicted recommendations are not too different from choosing the most populous counties in the US. Additionally, our lasso regression also resulted in negative values of predicted Diabetes_Number, which is confusing from an interpretability standpoint.
